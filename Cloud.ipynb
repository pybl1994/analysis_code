# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import nc_time_axis

from astropy.table import QTable

# %%
# define eccentricity range

e_range =['circ']

# define path 

data_dir_file = []

for i in range(len(e_range)):
    data_dir_file.append('/nobackup/pybl/cesm_sims/archive/b.e21.BWma1850.f19_g17.new_'+ e_range[i]+'.001/atm/hist/')
    
# define specific path
# we don't want to show variable ending with 'TOA' because it stands for top of atmosphere and it is used for 
# comparingwith observation with an additional atmospheric layer. To show energy budget, please use EEI=FSNT-FLNT.

Path_SOLIN     = []
Path_FLNT      = []
Path_FLNTC     = []  # CLEARSKY
Path_FSNT      = []
Path_FSNTC     = []  # CLEARSKY
Path_FSUTOA    = []

Path_FSNS      = []
Path_FSNSC     = []  # CLEARSKY

Path_FLNS      = []
Path_FLNSC      = []

Path_TS        = []

Path_T        = []

Path_ICEFRAC   = []

Path_CLDTOT    = []
Path_CLDLOW    = []
Path_CLDHGH    = []
Path_CLOUD     = []
Path_CLDICE     = []

Path_SWCF     = []
Path_LWCF     = []


for i in range(len(data_dir_file)):
    Path_SOLIN.append(data_dir_file[i]+'SOLIN_'+ e_range[i] +'_obl0.nc') 
    
    Path_FLNT.append(data_dir_file[i]+'FLNT_'+ e_range[i] +'_obl0.nc') 
    
    Path_FLNS.append(data_dir_file[i]+'FLNS_'+ e_range[i] +'_obl0.nc')
    
    Path_FLNSC.append(data_dir_file[i]+'FLNSC_'+ e_range[i] +'_obl0.nc')
    
    Path_FLNTC.append(data_dir_file[i]+'FLNTC_'+ e_range[i] +'_obl0.nc') 
    
    Path_FSNT.append(data_dir_file[i]+'FSNT_'+ e_range[i] +'_obl0.nc') 
    
    Path_FSNTC.append(data_dir_file[i]+'FSNTC_'+ e_range[i] +'_obl0.nc') 
    
    Path_FSNS.append(data_dir_file[i]+'FSNS_'+ e_range[i] +'_obl0.nc') 
    
    Path_FSNSC.append(data_dir_file[i]+'FSNSC_'+ e_range[i] +'_obl0.nc') 
    
    Path_FSUTOA.append(data_dir_file[i]+'FSUTOA_'+ e_range[i] +'_obl0.nc')
    
    Path_TS.append(data_dir_file[i]+'TS_'+ e_range[i] +'_obl0.nc')
    
    Path_ICEFRAC.append(data_dir_file[i]+'ICEFRAC_'+ e_range[i] +'_obl0.nc')
    
    Path_CLDTOT.append(data_dir_file[i]+'CLDTOT_'+ e_range[i] +'_obl0.nc')
    
    Path_CLDLOW.append(data_dir_file[i]+'CLDLOW_'+ e_range[i] +'_obl0.nc')
    
    Path_CLDHGH.append(data_dir_file[i]+'CLDHGH_'+ e_range[i] +'_obl0.nc')
    
    Path_T.append(data_dir_file[i]+'T_'+ e_range[i] +'_obl0.nc')
    
    Path_CLOUD.append(data_dir_file[i]+'CLOUD_'+ e_range[i] +'_obl0.nc')
    
    Path_CLDICE.append(data_dir_file[i]+'CLDICE_'+ e_range[i] +'_obl0.nc')
    
    Path_LWCF.append(data_dir_file[i]+'LWCF_'+ e_range[i] +'_obl0.nc')
    
    Path_SWCF.append(data_dir_file[i]+'SWCF_'+ e_range[i] +'_obl0.nc')

# Import data
# each file has 5 case elements

SOLIN_circ      =[]
FLNT_circ       =[]
FLNS_circ       =[]
FLNSC_circ       =[]
FLNTC_circ      =[]
FSNT_circ       =[]
FSNTC_circ      =[]
FSNS_circ       =[]
FSNSC_circ      =[]
FSUTOA_circ     =[]
TS_circ         =[]
ICEFRAC_circ    =[]
CLDTOT_circ     =[]
CLDLOW_circ     =[]
CLDHGH_circ     =[]
CLDICE_circ     =[]
T_circ          =[]
CLOUD_circ      =[]
SWCF_circ       =[]
LWCF_circ       =[]
 
for i in range(len(e_range)):

    SOLIN_circ.append(xr.open_mfdataset(Path_SOLIN[i]))
    FLNT_circ.append(xr.open_mfdataset(Path_FLNT[i]))
    FLNS_circ.append(xr.open_mfdataset(Path_FLNS[i]))
    FLNSC_circ.append(xr.open_mfdataset(Path_FLNSC[i]))
    FLNTC_circ.append(xr.open_mfdataset(Path_FLNTC[i]))
    FSNT_circ.append(xr.open_mfdataset(Path_FSNT[i]))
    FSNTC_circ.append(xr.open_mfdataset(Path_FSNTC[i]))
    FSNS_circ.append(xr.open_mfdataset(Path_FSNS[i]))
    FSNSC_circ.append(xr.open_mfdataset(Path_FSNSC[i]))
    FSUTOA_circ.append(xr.open_mfdataset(Path_FSUTOA[i]))
    TS_circ.append(xr.open_mfdataset(Path_TS[i]))
    T_circ.append(xr.open_mfdataset(Path_T[i]))
    ICEFRAC_circ.append(xr.open_mfdataset(Path_ICEFRAC[i]))
    CLDTOT_circ.append(xr.open_mfdataset(Path_CLDTOT[i]))
    CLDLOW_circ.append(xr.open_mfdataset(Path_CLDLOW[i]))
    CLDHGH_circ.append(xr.open_mfdataset(Path_CLDHGH[i]))
    CLDICE_circ.append(xr.open_mfdataset(Path_CLDICE[i]))
    
    CLOUD_circ.append(xr.open_mfdataset(Path_CLOUD[i]))
    SWCF_circ.append(xr.open_mfdataset(Path_SWCF[i]))
    LWCF_circ.append(xr.open_mfdataset(Path_LWCF[i]))

# %%
# define eccentricity range

e_range =['e4']

# define path 

data_dir_file = []

for i in range(len(e_range)):
    data_dir_file.append('/nobackup/pybl/cesm_sims/archive/b.e21.BWma1850.f19_g17.new_'+ e_range[i]+'_test.001/atm/hist/')
    
# define specific path
# we don't want to show variable ending with 'TOA' because it stands for top of atmosphere and it is used for 
# comparingwith observation with an additional atmospheric layer. To show energy budget, please use EEI=FSNT-FLNT.

Path_SOLIN     = []
Path_FLNT      = []

Path_FLNS      = []
Path_FLNSC     = []

Path_FLNTC     = []  # CLEARSKY
Path_FSNT      = []
Path_FSNTC     = []  # CLEARSKY
Path_FSUTOA    = []

# Path_FSNS      = []
# Path_FSNSC     = []  # CLEARSKY

Path_TS        = []

Path_T         = []
Path_ICEFRAC   = []

Path_CLDTOT    = []
Path_CLDLOW    = []
Path_CLDHGH    = []
Path_CLOUD    = []
Path_CLDICE     = []

Path_SWCF     = []
Path_LWCF     = []

for i in range(len(data_dir_file)):
    Path_SOLIN.append(data_dir_file[i]+'SOLIN_'+ e_range[i] +'_merge.nc') 
    
    Path_FLNT.append(data_dir_file[i]+'FLNT_'+ e_range[i] +'_merge.nc')
    
    Path_FLNS.append(data_dir_file[i]+'FLNS_'+ e_range[i] +'_merge.nc')
    
    Path_FLNTC.append(data_dir_file[i]+'FLNTC_'+ e_range[i] +'_merge.nc') 
    
    Path_FSNT.append(data_dir_file[i]+'FSNT_'+ e_range[i] +'_merge.nc') 
    
    Path_FSNTC.append(data_dir_file[i]+'FSNTC_'+ e_range[i] +'_merge.nc') 
    
    Path_FSNS.append(data_dir_file[i]+'FSNS_'+ e_range[i] +'_merge.nc') 
    
    Path_FSNSC.append(data_dir_file[i]+'FSNSC_'+ e_range[i] +'_merge.nc') 
    
    Path_FLNSC.append(data_dir_file[i]+'FLNSC_'+ e_range[i] +'_merge.nc') 
    
    Path_FSUTOA.append(data_dir_file[i]+'FSUTOA_'+ e_range[i] +'_merge.nc')
    
    Path_TS.append(data_dir_file[i]+'TS_'+ e_range[i] +'_merge.nc')
    
    Path_T.append(data_dir_file[i]+'T_'+ e_range[i] +'_merge.nc')
    
    Path_ICEFRAC.append(data_dir_file[i]+'ICEFRAC_'+ e_range[i] +'_merge.nc')
    
    Path_CLDTOT.append(data_dir_file[i]+'CLDTOT_'+ e_range[i] +'_merge.nc')
    
    Path_CLDLOW.append(data_dir_file[i]+'CLDLOW_'+ e_range[i] +'_merge.nc')
    
    Path_CLDHGH.append(data_dir_file[i]+'CLDHGH_'+ e_range[i] +'_merge.nc')
    
    Path_CLOUD.append(data_dir_file[i]+'CLOUD_'+ e_range[i] +'_merge.nc')
    
    Path_LWCF.append(data_dir_file[i]+'LWCF_'+ e_range[i] +'_merge.nc')
    
    Path_SWCF.append(data_dir_file[i]+'SWCF_'+ e_range[i] +'_merge.nc')
    
    Path_CLDICE.append(data_dir_file[i]+'CLDICE_'+ e_range[i] +'_merge.nc')

# Import data
# each file has 5 case elements

SOLIN_e4      =[]
FLNT_e4       =[]
FLNS_e4       =[]
FLNSC_e4      =[]
FLNTC_e4      =[]
FSNT_e4       =[]
FSNTC_e4      =[]
FSNS_e4       =[]
FSNSC_e4      =[]
FSUTOA_e4     =[]
TS_e4         =[]
T_e4          =[]
ICEFRAC_e4    =[]
CLDTOT_e4     =[]
CLDLOW_e4     =[]
CLDHGH_e4     =[]
CLOUD_e4     =[]
SWCF_e4      =[]
LWCF_e4       =[]
CLDICE_e4      =[]

for i in range(len(e_range)):

    SOLIN_e4.append(xr.open_mfdataset(Path_SOLIN[i]))
    FLNT_e4.append(xr.open_mfdataset(Path_FLNT[i]))
    FLNS_e4.append(xr.open_mfdataset(Path_FLNS[i]))
    FLNTC_e4.append(xr.open_mfdataset(Path_FLNTC[i]))
    FSNT_e4.append(xr.open_mfdataset(Path_FSNT[i]))
    FSNTC_e4.append(xr.open_mfdataset(Path_FSNTC[i]))
    FSNS_e4.append(xr.open_mfdataset(Path_FSNS[i]))
    FSNSC_e4.append(xr.open_mfdataset(Path_FSNSC[i]))
    FLNSC_e4.append(xr.open_mfdataset(Path_FLNSC[i]))
    FSUTOA_e4.append(xr.open_mfdataset(Path_FSUTOA[i]))
    TS_e4.append(xr.open_mfdataset(Path_TS[i]))
    T_e4.append(xr.open_mfdataset(Path_T[i]))
    ICEFRAC_e4.append(xr.open_mfdataset(Path_ICEFRAC[i]))
    CLDTOT_e4.append(xr.open_mfdataset(Path_CLDTOT[i]))
    CLDLOW_e4.append(xr.open_mfdataset(Path_CLDLOW[i]))
    CLDHGH_e4.append(xr.open_mfdataset(Path_CLDHGH[i]))
    CLOUD_e4.append(xr.open_mfdataset(Path_CLOUD[i]))
    SWCF_e4.append(xr.open_mfdataset(Path_SWCF[i]))
    LWCF_e4.append(xr.open_mfdataset(Path_LWCF[i]))
    
    CLDICE_e4.append(xr.open_mfdataset(Path_CLDICE[i]))

# %%
weights=np.cos(np.deg2rad(TS_circ[0].TS.lat))

# %%
ds10=xr.open_mfdataset("/nobackup/pybl/cesm_sims/archive/b.e21.BWma1850.f19_g17.new_e4.001/atm/hist/b.e21.BWma1850.f19_g17.new_e4.001.cam.h0.0014-10.nc")

ds10
# Out:
# <xarray.Dataset>
# Dimensions:                  (ilev: 71, lat: 96, lev: 70, lon: 144, nbnd: 2, time: 1, zlon: 1)
# Coordinates:
#   * lat                      (lat) float64 -90.0 -88.11 -86.21 ... 88.11 90.0
#   * lon                      (lon) float64 0.0 2.5 5.0 7.5 ... 352.5 355.0 357.5
#   * zlon                     (zlon) float64 0.0
#   * lev                      (lev) float64 5.96e-06 9.827e-06 ... 976.3 992.6
#   * ilev                     (ilev) float64 4.5e-06 7.42e-06 ... 985.1 1e+03
#   * time                     (time) object 0014-11-01 00:00:00
# Dimensions without coordinates: nbnd
# Data variables:
#     gw                       (lat) float64 dask.array<chunksize=(96,), meta=np.ndarray>
#     zlon_bnds                (zlon, nbnd) float64 dask.array<chunksize=(1, 2), meta=np.ndarray>
#     hyam                     (lev) float64 dask.array<chunksize=(70,), meta=np.ndarray>
#     hybm                     (lev) float64 dask.array<chunksize=(70,), meta=np.ndarray>
# ...

# %%
ds4=xr.open_mfdataset("/nobackup/pybl/cesm_sims/archive/b.e21.BWma1850.f19_g17.new_e4.001/atm/hist/b.e21.BWma1850.f19_g17.new_e4.001.cam.h0.0015-03.nc")

ds4
# Out:
# <xarray.Dataset>
# Dimensions:                  (ilev: 71, lat: 96, lev: 70, lon: 144, nbnd: 2, time: 1, zlon: 1)
# Coordinates:
#   * lat                      (lat) float64 -90.0 -88.11 -86.21 ... 88.11 90.0
#   * lon                      (lon) float64 0.0 2.5 5.0 7.5 ... 352.5 355.0 357.5
#   * zlon                     (zlon) float64 0.0
#   * lev                      (lev) float64 5.96e-06 9.827e-06 ... 976.3 992.6
#   * ilev                     (ilev) float64 4.5e-06 7.42e-06 ... 985.1 1e+03
#   * time                     (time) object 0015-04-01 00:00:00
# Dimensions without coordinates: nbnd
# Data variables:
#     gw                       (lat) float64 dask.array<chunksize=(96,), meta=np.ndarray>
#     zlon_bnds                (zlon, nbnd) float64 dask.array<chunksize=(1, 2), meta=np.ndarray>
#     hyam                     (lev) float64 dask.array<chunksize=(70,), meta=np.ndarray>
#     hybm                     (lev) float64 dask.array<chunksize=(70,), meta=np.ndarray>
# ...

# %%
ds4.V.plot()
# Out:
# (array([2.22000e+02, 1.28300e+03, 9.40900e+03, 3.90110e+04, 3.05665e+05,
#         5.40448e+05, 5.91170e+04, 1.01710e+04, 2.06100e+03, 2.93000e+02]),
#  array([-37.87441  , -30.50275  , -23.131092 , -15.759434 ,  -8.387775 ,
#          -1.0161171,   6.355541 ,  13.7272   ,  21.098858 ,  28.470516 ,
#          35.842175 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
ds10.V.plot()
# Out:
# (array([2.08000e+02, 2.85100e+03, 1.29880e+04, 6.91560e+04, 3.06057e+05,
#         4.52745e+05, 9.30760e+04, 2.31260e+04, 6.13200e+03, 1.34100e+03]),
#  array([-37.514523 , -30.183422 , -22.852322 , -15.52122  ,  -8.190119 ,
#          -0.8590183,   6.4720826,  13.803184 ,  21.134285 ,  28.465385 ,
#          35.796486 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
ds4.VT
# Out:
# <xarray.DataArray 'VT' (time: 1, lev: 70, lat: 96, lon: 144)>
# dask.array<open_dataset-06d3c6b8630e66c67f8ee4557e88392fVT, shape=(1, 70, 96, 144), dtype=float32, chunksize=(1, 70, 96, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 84.32 86.21 88.11 90.0
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lev      (lev) float64 5.96e-06 9.827e-06 1.62e-05 ... 957.5 976.3 992.6
#   * time     (time) object 0015-04-01 00:00:00
# Attributes:
#     mdims:         1
#     units:         K m/s
#     long_name:     Meridional heat transport
#     cell_methods:  time: mean

# %%
ds4.date
# Out:
# <xarray.DataArray 'date' (time: 1)>
# dask.array<open_dataset-06d3c6b8630e66c67f8ee4557e88392fdate, shape=(1,), dtype=int32, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0015-04-01 00:00:00
# Attributes:
#     long_name:  current date (YYYYMMDD)

# %%
ds0=xr.open_mfdataset("/nobackup/pybl/cesm_sims/archive/b.e21.BWma1850.f19_g17.new_circ.001/atm/hist/b.e21.BWma1850.f19_g17.new_circ.001.cam.h0.0015-03.nc")

# %%
# a snapshot shows the decreased relative humidity (capacity of air for holding water vapor)

ds4.RELHUM[0].mean(dim='lon').plot(yincrease=False,yscale='log')

plt.ylim(1000,10)

plt.figure()

ds10.RELHUM[0].mean(dim='lon').plot(yincrease=False,yscale='log')

plt.ylim(1000,10)

plt.figure()

ds0.RELHUM[0].mean(dim='lon').plot(yincrease=False,yscale='log')

plt.ylim(1000,10)

plt.figure()

(ds4.RELHUM[0]-ds0.RELHUM[0]).mean(dim='lon').plot(yincrease=False,yscale='log')
plt.ylim(1000,90)
plt.figure()
plt.title('Relative Humidity Anomaly (e04 -e0) Snapshot on 0015-04')

ds4.RELHUM[0].weighted(np.cos(np.deg2rad(ds4.RELHUM[0].lat))).mean(dim=("lat","lon")).plot(y='lev', yincrease=False,yscale='log',label='e4')
ds0.RELHUM[0].weighted(np.cos(np.deg2rad(ds0.RELHUM[0].lat))).mean(dim=("lat","lon")).plot(y='lev', yincrease=False,yscale='log',label='e0')
#plt.ylim(1000,90)
plt.ylim(150,50)

plt.xlabel('Relative Humidity (%)')
plt.legend()

# %%
# a snapshot shows the decreased relative humidity (capacity of air for holding water vapor)

ds4.Q[0].mean(dim='lon').plot(yincrease=False,yscale='log')

plt.ylim(1000,100)

plt.figure()

ds0.Q[0].mean(dim='lon').plot(yincrease=False,yscale='log')

plt.ylim(1000,100)

plt.figure()

(ds4.Q[0]-ds0.Q[0]).mean(dim='lon').plot(yincrease=False,yscale='log')
plt.ylim(1000,90)
plt.figure()
plt.title('Relative Humidity Anomaly (e04 -e0) Snapshot on 0015-04')

ds4.Q[0].weighted(np.cos(np.deg2rad(ds4.Q[0].lat))).mean(dim=("lat","lon")).plot(y='lev', yincrease=False,yscale='log',label='e4')
ds0.Q[0].weighted(np.cos(np.deg2rad(ds0.Q[0].lat))).mean(dim=("lat","lon")).plot(y='lev', yincrease=False,yscale='log',label='e0')
plt.ylim(150,50)
plt.xlim(0,0.0001)
plt.xlabel('Relative Humidity (kg/kg)')
plt.legend()

# %%
print('e4,cloud water path',ds4.TGCLDLWP[0].weighted(np.cos(np.deg2rad(ds4.Q[0].lat))).mean(dim=("lat","lon")).values)
print('e0,cloud water path',ds0.TGCLDLWP[0].weighted(np.cos(np.deg2rad(ds4.Q[0].lat))).mean(dim=("lat","lon")).values)
# Out:
# e4,cloud water path 0.07178881195244013
# e0,cloud water path 0.06370300052349342

# %%
ds4.TGCLDLWP[0].plot()
plt.figure()
ds0.TGCLDLWP[0].plot()
plt.figure()
(ds4.TGCLDLWP[0]-ds0.TGCLDLWP[0]).plot()

# %%
# # a snapshot shows the increased meridional water transport at the equator and the northern hemisphere

# ds4.VQ[0].mean(dim='lon').plot(yincrease=False)

# plt.ylim(1000,100)

# plt.figure()

# ds0.VQ[0].mean(dim='lon').plot(yincrease=False)

# plt.ylim(1000,100)

# plt.figure()

# (ds4.VQ[0]-ds0.VQ[0]).mean(dim='lon').plot(yincrease=False)

# %%
def weighted_temporal_mean(ds, var):
    """
    weight by days in each month
    """
    # Determine the month length
    month_length = ds.time.dt.days_in_month

    # Calculate the weights
    wgts = month_length.groupby("time.year") / month_length.groupby("time.year").sum()

    # Make sure the weights in each year add up to 1
    np.testing.assert_allclose(wgts.groupby("time.year").sum(xr.ALL_DIMS), 1.0)

    # Subset our dataset for our variable
    obs = ds[var]

    # Setup our masking for nan values
    cond = obs.isnull()
    ones = xr.where(cond, 0.0, 1.0)

    # Calculate the numerator
    obs_sum = (obs * wgts).resample(time="AS").sum(dim="time")

    # Calculate the denominator
    ones_out = (ones * wgts).resample(time="AS").sum(dim="time")

    # Return the weighted average
    return obs_sum / ones_out

# %%
# plot zonal mean surface temperature
import cartopy.crs as ccrs
import matplotlib.gridspec as gridspec
plt.figure(figsize=(10,8))

zonalTS_e0=weighted_temporal_mean(TS_circ[0].sel(time=slice('0012-01', '0016-12')),"TS").mean(dim=("lon")).mean(dim='time')

zonalTS_e04=weighted_temporal_mean(TS_e4[0].sel(time=slice('0012-01', '0016-12')),"TS").mean(dim=("lon")).mean(dim='time')

(zonalTS_e04-zonalTS_e0).plot(label='zonal mean TS anomaly (e04-e0)')

plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('TS (K)',fontsize=20)

plt.legend(fontsize=20)
plt.tick_params(labelsize=20)


glbTS_e0=weighted_temporal_mean(TS_circ[0].sel(time=slice('0012-01', '0016-12')),"TS").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glbTS_e04=weighted_temporal_mean(TS_e4[0].sel(time=slice('0012-01', '0016-12')),"TS").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values



TS_e0=weighted_temporal_mean(TS_circ[0].sel(time=slice('0012-01', '0016-12')),"TS").mean(dim='time')

TS_e04=weighted_temporal_mean(TS_e4[0].sel(time=slice('0012-01', '0016-12')),"TS").mean(dim='time')


#

gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(11,15))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0],projection=ccrs.Robinson()) # row 0, col 0
ax.set_global() 
ax.coastlines()

fg=(TS_e04-TS_e0).plot(transform=ccrs.PlateCarree())

# %%
# globalTS_e0=weighted_temporal_mean(TS_obl0_circ[0].sel(time=slice('0012-01', '0016-12')),"TS").weighted(np.cos(np.deg2rad(TS_obl0_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
# globalTS_e04=weighted_temporal_mean(TS_obl0_circ[1].sel(time=slice('0012-01', '0016-12')),"TS").weighted(np.cos(np.deg2rad(TS_obl0_circ[1].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

# print(globalTS_e0)
# print(globalTS_e04)
# print('anomaly',globalTS_e04-globalTS_e0)

# %%
# plot zonal mean surface temperature

plt.figure(figsize=(10,8))

zonalT_e0=weighted_temporal_mean(T_circ[0].sel(time=slice('0012-01', '0016-12')),"T").mean(dim=("lon")).mean(dim='time')

zonalT_e04=weighted_temporal_mean(T_e4[0].sel(time=slice('0010-01', '0014-12')),"T").mean(dim=("lon")).mean(dim='time')

fg=(zonalT_e04-zonalT_e0)[-44:-1,:].plot(yscale='log',yincrease=False,cmap='seismic')

zonalT_diff_contour=(zonalT_e04-zonalT_e0)[-44:-1,:].plot.contour(x='lat',cmap='gray',yscale='log',yincrease=False)

fg.colorbar.ax.tick_params(labelsize=15)

fg.colorbar.set_label(label="zonal mean T anomaly (e04-e0)", size=15)


plt.clabel(zonalT_diff_contour, inline=True, fontsize=20,fmt='%1.f')

plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('Pressure (hPa)',fontsize=20)

plt.tick_params(labelsize=20)

# %%
# plot zonal mean cloud

plt.figure(figsize=(10,8))

zonalCLOUD_e0=weighted_temporal_mean(CLOUD_circ[0].sel(time=slice('0012-01', '0016-12')),"CLOUD").mean(dim=("lon")).mean(dim='time')

zonalCLOUD_e04=weighted_temporal_mean(CLOUD_e4[0].sel(time=slice('0010-01', '0014-12')),"CLOUD").mean(dim=("lon")).mean(dim='time')

fg=(zonalCLOUD_e04-zonalCLOUD_e0)[-35:-1,:].plot(yscale='log',yincrease=False,cmap='seismic')

zonalCLOUD_diff_contour=(zonalCLOUD_e04-zonalCLOUD_e0)[-44:-1,:].plot.contour(x='lat',cmap='gray',yscale='log',yincrease=False)

fg.colorbar.ax.tick_params(labelsize=15)

fg.colorbar.set_label(label="zonal mean CLOUD anomaly (e04-e0)", size=15)


plt.clabel(zonalCLOUD_diff_contour, inline=True, fontsize=20,fmt='%1.f')

plt.title('Cloud Fraction')

plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('Pressure (hPa)',fontsize=20)

plt.tick_params(labelsize=20)

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(11,15))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0],projection=ccrs.Robinson()) # row 0, col 0
ax.set_global() 
ax.coastlines()


CLDLOW_circ[0].CLDLOW.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').sel(month=4).plot(cmap='RdYlBu_r',transform=ccrs.PlateCarree())

ax = plt.subplot(gs[1, 0],projection=ccrs.Robinson()) # row 0, col 0
ax.set_global() 
ax.coastlines()


CLDLOW_e4[0].CLDLOW.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').sel(month=4).plot(cmap='RdYlBu_r',transform=ccrs.PlateCarree())

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(11,15))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0],projection=ccrs.Robinson()) # row 0, col 0
ax.set_global() 
ax.coastlines()


CLDHGH_circ[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').sel(month=4).plot(cmap='RdYlBu_r',transform=ccrs.PlateCarree())

ax = plt.subplot(gs[1, 0],projection=ccrs.Robinson()) # row 0, col 0
ax.set_global() 
ax.coastlines()


CLDHGH_e4[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').sel(month=4).plot(cmap='RdYlBu_r',transform=ccrs.PlateCarree())

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(10,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0



CLDHGH_circ[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').mean(dim='lon').plot(cmap='RdYlBu_r',x='month')

ax = plt.subplot(gs[1, 0]) # row 0, col 0

CLDHGH_e4[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').mean(dim='lon').plot(cmap='RdYlBu_r',x='month')

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(10,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0



CLDLOW_circ[0].CLDLOW.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').mean(dim='lon').plot(cmap='RdYlBu_r',x='month')

ax = plt.subplot(gs[1, 0]) # row 0, col 0

CLDLOW_e4[0].CLDLOW.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').mean(dim='lon').plot(cmap='RdYlBu_r',x='month')

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(10,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0



CLDTOT_circ[0].CLDTOT.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').mean(dim='lon').plot(cmap='RdYlBu_r',x='month')

ax = plt.subplot(gs[1, 0]) # row 0, col 0

CLDTOT_e4[0].CLDTOT.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').mean(dim='lon').plot(cmap='RdYlBu_r',x='month')

# %%
# plot zonal mean CLDICE

plt.figure(figsize=(10,8))



zonalCLDICE_e0=CLDICE_circ[0].CLDICE.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)


zonalCLDICE_e04=CLDICE_e4[0].CLDICE.sel(time=slice('0010-01', '0014-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)


fg=(zonalCLDICE_e04-zonalCLDICE_e0)[-35:-1,:].plot(yscale='log',yincrease=False)


#zonalCLDICE_diff_contour=(zonalCLDICE_e04-zonalCLDICE_e0)[-44:-1,:].plot.contour(x='lat',cmap='gray',yscale='log',yincrease=False)

fg.colorbar.ax.tick_params(labelsize=15)

fg.colorbar.set_label(label="zonal mean CLDICE anomaly (e04-e0)", size=15)


# plt.clabel(zonalCLDICE_diff_contour, inline=True, fontsize=20,fmt='%1.f')

plt.title('CLDICE Fraction')

plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('Pressure (hPa)',fontsize=20)

plt.tick_params(labelsize=20)

# %%
CLOUD_circ[0].CLOUD
# Out:
# <xarray.DataArray 'CLOUD' (time: 192, lev: 70, lat: 96, lon: 144)>
# dask.array<open_dataset-21ec8baf57006059f6264a1df1dfc364CLOUD, shape=(192, 70, 96, 144), dtype=float32, chunksize=(192, 70, 96, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 84.32 86.21 88.11 90.0
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lev      (lev) float64 5.96e-06 9.827e-06 1.62e-05 ... 957.5 976.3 992.6
#   * time     (time) object 0001-05-01 00:00:00 ... 0017-04-01 00:00:00
# Attributes:
#     mdims:         1
#     units:         fraction
#     long_name:     Cloud fraction
#     cell_methods:  time: mean

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(10,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0



A=CLDTOT_circ[0].CLDTOT.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon"))

A.plot()

B=CLDTOT_e4[0].CLDTOT.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon"))

B.plot()

C=weighted_temporal_mean(CLDTOT_circ[0].sel(time=slice('0012-01', '0016-12')),"CLDTOT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

D=weighted_temporal_mean(CLDTOT_e4[0].sel(time=slice('0012-01', '0016-12')),"CLDTOT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

print('CLDTOT, e=0, Global',C)

print('CLDTOT, e=0.4, Global',D)
# Out:
# CLDTOT, e=0, Global 0.704508717412794
# CLDTOT, e=0.4, Global 0.7275379335131418

# %%
File_land = "/nobackup/pybl/cesm_sims/archive/b.e21.BWma1850.f19_g17.new_circ_psg.001/lnd/hist/b.e21.BWma1850.f19_g17.new_circ_psg.001.clm2.h0.0014-04.nc" #file name

DataSet_land = xr.open_dataset(File_land) #open the file

File_CAM = "/nobackup/pybl/cesm2/archive/b.e21.BWma1850.f19_g17.e0_obl0.001/atm/hist/b.e21.BWma1850.f19_g17.e0_obl0.001.cam.h0.0001-03.nc" #file name

DataSet_CAM = xr.open_dataset(File_CAM) #open the file

# we can only assign a new coord to the data set (main), but not the data array(variables)
# we should truncate the very large orginal .nc file into smaller .nc file with requried variables
# to save the Jupyter notebook memory and allow it to run (hint: ncrcat)

File_CAM = "/nobackup/pybl/cesm2/archive/b.e21.BWma1850.f19_g17.e0_obl0.001/atm/hist/b.e21.BWma1850.f19_g17.e0_obl0.001.cam.h0.0001-03.nc" #file name

DataSet_CAM = xr.open_dataset(File_CAM) #open the file

DataSet_CAM.coords['mask'] = (('lat', 'lon'), DataSet_land.landmask)

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(10,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0



CLDTOT_circ[0].CLDTOT.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).plot(label='CLDTOT, e=0, land',color='green')

CLDTOT_e4[0].CLDTOT.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).plot(label='CLDTOT, e=0.4, land',color='red')

CLDTOT_circ[0].CLDTOT.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).plot(linestyle='--',label='CLDTOT, e=0, ocean',color='green')

CLDTOT_e4[0].CLDTOT.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).plot(linestyle='--',label='CLDTOT, e=0.4, ocean',color='red')

plt.legend()

C=weighted_temporal_mean(CLDTOT_circ[0].where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')),"CLDTOT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

D=weighted_temporal_mean(CLDTOT_e4[0].where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')),"CLDTOT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

E=weighted_temporal_mean(CLDTOT_circ[0].where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')),"CLDTOT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

F=weighted_temporal_mean(CLDTOT_e4[0].where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')),"CLDTOT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

print('CLDTOT, e=0, LAND',C)

print('CLDTOT, e=0.4, LAND',D)

print('CLDTOT, e=0, OCN',E)

print('CLDTOT, e=0.4, OCN',F)
# Out:
# /nobackup/cemac/software/compilers/python3/3.7.8/1/default/conda/lib/python3.7/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /nobackup/cemac/software/compilers/python3/3.7.8/1/default/conda/lib/python3.7/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /nobackup/cemac/software/compilers/python3/3.7.8/1/default/conda/lib/python3.7/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /nobackup/cemac/software/compilers/python3/3.7.8/1/default/conda/lib/python3.7/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(10,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0



CLDLOW_circ[0].CLDLOW.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).plot(label='CLDLOW, e=0, land',color='green')

CLDLOW_e4[0].CLDLOW.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).plot(label='CLDLOW, e=0.4, land',color='red')

CLDLOW_circ[0].CLDLOW.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).plot(linestyle='--',label='CLDLOW, e=0, ocean',color='green')

CLDLOW_e4[0].CLDLOW.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).plot(linestyle='--',label='CLDLOW, e=0.4, ocean',color='red')

plt.legend()

C=weighted_temporal_mean(CLDLOW_circ[0].where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')),"CLDLOW").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

D=weighted_temporal_mean(CLDLOW_e4[0].where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')),"CLDLOW").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

E=weighted_temporal_mean(CLDLOW_circ[0].where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')),"CLDLOW").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

F=weighted_temporal_mean(CLDLOW_e4[0].where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')),"CLDLOW").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

print('CLDLOW, e=0, LAND',C)

print('CLDLOW, e=0.4, LAND',D)

print('CLDLOW, e=0, OCN',E)

print('CLDLOW, e=0.4, OCN',F)
# Out:
# /nobackup/cemac/software/compilers/python3/3.7.8/1/default/conda/lib/python3.7/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /nobackup/cemac/software/compilers/python3/3.7.8/1/default/conda/lib/python3.7/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /nobackup/cemac/software/compilers/python3/3.7.8/1/default/conda/lib/python3.7/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /nobackup/cemac/software/compilers/python3/3.7.8/1/default/conda/lib/python3.7/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 2)

plt.figure(figsize=(20,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0

A=TS_e4[0].TS.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

B=TS_e4[0].TS.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

C=TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

D=TS_circ[0].TS.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

E=TS_circ[0].TS.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

F=TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

A.plot(label='e=0.4, land',color='red')
B.plot(label='e=0.4, ocean',color='blue')
C.plot(label='e=0.4, global',color='green')

D.plot(label='e=0, land',linestyle='--',color='red')
E.plot(label='e=0, ocean',linestyle='--',color='blue')
F.plot(label='e=0, global',linestyle='--',color='green')

plt.ylabel('TS (K)')
plt.legend()

ax = plt.subplot(gs[0, 1]) # row 0, col 0

A=CLDTOT_e4[0].CLDTOT.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDTOT_circ[0].CLDTOT.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

B=CLDTOT_e4[0].CLDTOT.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDTOT_circ[0].CLDTOT.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

C=CLDTOT_e4[0].CLDTOT.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDTOT_circ[0].CLDTOT.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

D=CLDTOT_circ[0].CLDTOT.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDTOT_circ[0].CLDTOT.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

E=CLDTOT_circ[0].CLDTOT.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDTOT_circ[0].CLDTOT.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

F=CLDTOT_circ[0].CLDTOT.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDTOT_circ[0].CLDTOT.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

A.plot(label='e=0.4, land',color='red')
B.plot(label='e=0.4, ocean',color='blue')
C.plot(label='e=0.4, global',color='green')

D.plot(label='e=0, land',linestyle='--',color='red')
E.plot(label='e=0, ocean',linestyle='--',color='blue')
F.plot(label='e=0, global',linestyle='--',color='green')

plt.ylabel('CLDTOT')
plt.legend()


ax = plt.subplot(gs[1, 0]) # row 0, col 0

A=CLDLOW_e4[0].CLDLOW.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDLOW_circ[0].CLDLOW.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

B=CLDLOW_e4[0].CLDLOW.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDLOW_circ[0].CLDLOW.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

C=CLDLOW_e4[0].CLDLOW.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDLOW_circ[0].CLDLOW.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

D=CLDLOW_circ[0].CLDLOW.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDLOW_circ[0].CLDLOW.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

E=CLDLOW_circ[0].CLDLOW.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDLOW_circ[0].CLDLOW.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

F=CLDLOW_circ[0].CLDLOW.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDLOW_circ[0].CLDLOW.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')



A.plot(label='e=0.4, land',color='red')
B.plot(label='e=0.4, ocean',color='blue')
C.plot(label='e=0.4, global',color='green')

D.plot(label='e=0, land',linestyle='--',color='red')
E.plot(label='e=0, ocean',linestyle='--',color='blue')
F.plot(label='e=0, global',linestyle='--',color='green')

plt.ylabel('CLDLOW')
plt.legend()


ax = plt.subplot(gs[1, 1]) # row 0, col 0

A=CLDHGH_e4[0].CLDHGH.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

B=CLDHGH_e4[0].CLDHGH.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

C=CLDHGH_e4[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')
D=CLDHGH_circ[0].CLDHGH.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

E=CLDHGH_circ[0].CLDHGH.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

F=CLDHGH_circ[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')
print(np.mean(A.values))
print(np.mean(B.values))
print(np.mean(C.values))
print(np.mean(D.values))
print(np.mean(E.values))
print(np.mean(F.values))

A.plot(label='e=0.4, land',color='red')
B.plot(label='e=0.4, ocean',color='blue')
C.plot(label='e=0.4, global',color='green')

D.plot(label='e=0, land',linestyle='--',color='red')
E.plot(label='e=0, ocean',linestyle='--',color='blue')
F.plot(label='e=0, global',linestyle='--',color='green')
plt.ylabel('CLDHGH')
plt.legend()
# Out:
# 0.4533314064643365
# 0.458350021271235
# 0.4565551041384415
# 0.4437801895084396
# 0.43035529552849466
# 0.43515673439909724

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 1)

plt.figure(figsize=(12,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0

fg=T_e4[0].T.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time').where((T_e4[0].lev > 1) & (T_e4[0].lev < 1000)).plot(x='month',yincrease=False,yscale='log',ax=ax)
# plt.ylim(10**(-4),10**(-5))

plt.ylim(1000,1)
fg.colorbar.set_label(label="T (K)", size=15)

ax = plt.subplot(gs[1, 0]) # row 0, col 0

fg=T_circ[0].T.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time').where((T_e4[0].lev > 1) & (T_e4[0].lev < 1000)).plot(x='month',yincrease=False,yscale='log',ax=ax)

fg.colorbar.set_label(label="T (K)", size=15)

plt.ylim(1000,1)
# Out:
# (1000, 1)

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 2)

plt.figure(figsize=(20,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0


# LWCF

A=LWCF_circ[0].LWCF.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

B=LWCF_e4[0].LWCF.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

C=LWCF_circ[0].LWCF.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

D=LWCF_e4[0].LWCF.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

E=LWCF_circ[0].LWCF.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

F=LWCF_e4[0].LWCF.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')


D.plot(label='e=0.4, land',color='red')
F.plot(label='e=0.4, ocean',color='blue')
B.plot(label='e=0.4, global',color='green')

C.plot(label='e=0, land',linestyle='--',color='red')
E.plot(label='e=0, ocean',linestyle='--',color='blue')
A.plot(label='e=0, global',linestyle='--',color='green')


# plt.plot(range(1,13,1),[np.mean(B)]*12, color='orange', linestyle='--',label='e=0.4, LWCF, mean')
plt.legend()

plt.ylabel('LWCF $Wm^{-2}$')


ax = plt.subplot(gs[0, 1]) # row 0, col 1

A=SWCF_circ[0].SWCF.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

B=SWCF_e4[0].SWCF.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

C=SWCF_circ[0].SWCF.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

D=SWCF_e4[0].SWCF.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

E=SWCF_circ[0].SWCF.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

F=SWCF_e4[0].SWCF.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')


# plt.plot(range(1,13,1),[np.mean(B)]*12, color='orange', linestyle='--',label='e=0.4, SWCF, mean')

D.plot(label='e=0.4, land',color='red')
F.plot(label='e=0.4, ocean',color='blue')
B.plot(label='e=0.4, global',color='green')

C.plot(label='e=0, land',linestyle='--',color='red')
E.plot(label='e=0, ocean',linestyle='--',color='blue')
A.plot(label='e=0, global',linestyle='--',color='green')

print(np.mean(A.values))
print(np.mean(B.values))
print(np.mean(C.values))
print(np.mean(D.values))
print(np.mean(E.values))
print(np.mean(F.values))


plt.ylabel('SWCF $Wm^{-2}$')
plt.legend()
# Out:
# -48.67854162505628
# -43.22561657374058
# -32.16833728913818
# -31.61202478196014
# -57.871230153619386
# -49.6919285507196

# %%
# plot zonal mean cloud
gs = gridspec.GridSpec(2, 2)

plt.figure(figsize=(20,16))

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.8, 
                    top=0.8, 
                    wspace=0.5, 
                    hspace=0.5)

ax = plt.subplot(gs[0, 0]) # row 0, col 0


# FLNT

A=FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

B=FLNT_e4[0].FLNT.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

C=FLNT_circ[0].FLNT.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

D=FLNT_e4[0].FLNT.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

E=FLNT_circ[0].FLNT.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

F=FLNT_e4[0].FLNT.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')


D.plot(label='e=0.4, land',color='red')
F.plot(label='e=0.4, ocean',color='blue')
B.plot(label='e=0.4, global',color='green')

C.plot(label='e=0, land',linestyle='--',color='red')
E.plot(label='e=0, ocean',linestyle='--',color='blue')
A.plot(label='e=0, global',linestyle='--',color='green')


# plt.plot(range(1,13,1),[np.mean(B)]*12, color='orange', linestyle='--',label='e=0.4, FLNT, mean')
plt.legend()

plt.ylabel('FLNT $Wm^{-2}$')


ax = plt.subplot(gs[0, 1]) # row 0, col 1

A=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

B=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

C=FSNT_circ[0].FSNT.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

D=FSNT_e4[0].FSNT.where(DataSet_CAM.mask == 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

E=FSNT_circ[0].FSNT.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')

F=FSNT_e4[0].FSNT.where(DataSet_CAM.mask != 1).sel(time=slice('0012-01', '0016-12')).weighted(np.cos(np.deg2rad(CLDHGH_circ[0].CLDHGH.lat))).mean(dim=("lat","lon")).groupby('time.month').mean(dim='time')


# plt.plot(range(1,13,1),[np.mean(B)]*12, color='orange', linestyle='--',label='e=0.4, FSNT, mean')

D.plot(label='e=0.4, land',color='red')
F.plot(label='e=0.4, ocean',color='blue')
B.plot(label='e=0.4, global',color='green')

C.plot(label='e=0, land',linestyle='--',color='red')
E.plot(label='e=0, ocean',linestyle='--',color='blue')
A.plot(label='e=0, global',linestyle='--',color='green')

print(np.mean(A.values))
print(np.mean(B.values))
print(np.mean(C.values))
print(np.mean(D.values))
print(np.mean(E.values))
print(np.mean(F.values))


plt.ylabel('FSNT $Wm^{-2}$')
plt.legend()
# Out:
# 237.87419535534437
# 244.8607325525962
# 215.93683644288555
# 221.57712496568584
# 250.0886600293443
# 257.82477273120105

# %%
a = np.array(["lnd", "ocn", "glb"])
b = [283.2 , 290.8, 288.1]
c = [285.6, 292.2, 289.8]
t = QTable([a, b, c],
           names=('Surface Type', 'TS (e=0) ', 'TS (e=0.4) '),
           meta={'name': 'first table'})
print(t)
a = np.array(["lnd", "ocn", "glb"])

b = [ 0.64, 0.74, 0.70]
c = [ 0.66, 0.76, 0.73]
t = QTable([a, b, c],
           names=('Surface Type', 'CLDTOT (e=0) ', 'CLDTOT (e=0.4) '),
           meta={'name': 'first table'})
print(t)

a = np.array(["lnd", "ocn", "glb"])

b = [ 0.28, 0.52, 0.43]
c = [ 0.3, 0.51, 0.44]
t = QTable([a, b, c],
           names=('Surface Type', 'CLDLOW (e=0) ', 'CLDLOW (e=0.4) '),
           meta={'name': 'first table'})
print(t)

a = np.array(["lnd", "ocn", "glb"])

b = [ 0.44, 0.43, 0.44]
c = [ 0.45, 0.46, 0.46]
t = QTable([a, b, c],
           names=('Surface Type', 'CLDHGH (e=0) ', 'CLDHGH (e=0.4) '),
           meta={'name': 'first table'})
print(t)

a = np.array(["lnd", "ocn", "glb"])

b = [ 20.9, 24.1, 22.9]
c = [ 19.7, 23.3, 22.1]
t = QTable([a, b, c],
           names=('Surface Type', 'LWCF (e=0) ', 'LWCF (e=0.4) '),
           meta={'name': 'first table'})
print(t)

a = np.array(["lnd", "ocn", "glb"])

b = [ -32.2, -57.9, -48.7]
c = [ -31.6, -49.7, -43.2]
t = QTable([a, b, c],
           names=('Surface Type', 'SWCF (e=0) ', 'SWCF (e=0.4) '),
           meta={'name': 'first table'})
print(t)
# Out:
# Surface Type TS (e=0)  TS (e=0.4)
# ------------ --------- -----------
#          lnd     283.2       285.6
#          ocn     290.8       292.2
#          glb     288.1       289.8
# Surface Type CLDTOT (e=0)  CLDTOT (e=0.4)
# ------------ ------------- ---------------
#          lnd          0.64            0.66
#          ocn          0.74            0.76
#          glb           0.7            0.73
# Surface Type CLDLOW (e=0)  CLDLOW (e=0.4)
# ------------ ------------- ---------------
#          lnd          0.28             0.3
#          ocn          0.52            0.51
#          glb          0.43            0.44
# Surface Type CLDHGH (e=0)  CLDHGH (e=0.4)
# ------------ ------------- ---------------
#          lnd          0.44            0.45
#          ocn          0.43            0.46
#          glb          0.44            0.46
# Surface Type LWCF (e=0)  LWCF (e=0.4)
# ------------ ----------- -------------
#          lnd        20.9          19.7
# ...

# %%
lowcld_e0=weighted_temporal_mean(CLDLOW_circ[0].sel(time=slice('0012-01', '0016-12')),"CLDLOW").mean(dim=("lon")).mean(dim='time')
hghcld_e0=weighted_temporal_mean(CLDHGH_circ[0].sel(time=slice('0012-01', '0016-12')),"CLDHGH").mean(dim=("lon")).mean(dim='time')

lowcld_e04=weighted_temporal_mean(CLDLOW_e4[0].sel(time=slice('0012-01', '0016-12')),"CLDLOW").mean(dim=("lon")).mean(dim='time')

hghcld_e04=weighted_temporal_mean(CLDHGH_e4[0].sel(time=slice('0012-01', '0016-12')),"CLDHGH").mean(dim=("lon")).mean(dim='time')

plt.figure(figsize=(10,8))
(hghcld_e04-hghcld_e0).plot(label='high cloud anomaly (e04-e0)')

(lowcld_e04-lowcld_e0).plot(label='low cloud anomaly (e04-e0)')

plt.legend()


glb_lowcld_e0=weighted_temporal_mean(CLDLOW_circ[0].sel(time=slice('0012-01', '0016-12')),"CLDLOW").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
glb_hghcld_e0=weighted_temporal_mean(CLDHGH_circ[0].sel(time=slice('0012-01', '0016-12')),"CLDHGH").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_lowcld_e04=weighted_temporal_mean(CLDLOW_e4[0].sel(time=slice('0012-01', '0016-12')),"CLDLOW").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
glb_hghcld_e04=weighted_temporal_mean(CLDHGH_e4[0].sel(time=slice('0012-01', '0016-12')),"CLDHGH").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values


print('global mean high cloud anomaly ratio in percentage',100*(glb_hghcld_e04-glb_hghcld_e0)/glb_hghcld_e0)
print('global mean low cloud anomaly ratio in percentage',100*(glb_lowcld_e04-glb_lowcld_e0)/glb_lowcld_e0)
# Out:
# global mean high cloud anomaly ratio in percentage 4.979244488703075
# global mean low cloud anomaly ratio in percentage 0.5331571283650214

# %%
# TOA energy balance


plt.figure(figsize=(10,8))

# FLNT

zonalFLNT_e0=weighted_temporal_mean(FLNT_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNT").mean(dim=("lon")).mean(dim='time')

zonalFLNT_e04=weighted_temporal_mean(FLNT_e4[0].sel(time=slice('0012-01', '0016-12')),"FLNT").mean(dim=("lon")).mean(dim='time')

(zonalFLNT_e04-zonalFLNT_e0).plot(label='OLR')

# FSNT

zonalFSNT_e0=weighted_temporal_mean(FSNT_circ[0].sel(time=slice('0012-01', '0016-12')),"FSNT").mean(dim=("lon")).mean(dim='time')

zonalFSNT_e04=weighted_temporal_mean(FSNT_e4[0].sel(time=slice('0012-01', '0016-12')),"FSNT").mean(dim=("lon")).mean(dim='time')

(zonalFSNT_e04-zonalFSNT_e0).plot(label='ASR',color='red')


# FLNTC

zonalFLNTC_e0=weighted_temporal_mean(FLNTC_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNTC").mean(dim=("lon")).mean(dim='time')

zonalFLNTC_e04=weighted_temporal_mean(FLNTC_e4[0].sel(time=slice('0012-01', '0016-12')),"FLNTC").mean(dim=("lon")).mean(dim='time')

(zonalFLNTC_e04-zonalFLNTC_e0).plot(label='OLR(c)',linestyle='--',color='blue')


# FSNTC

zonalFSNTC_e0=weighted_temporal_mean(FSNTC_circ[0].sel(time=slice('0012-01', '0016-12')),"FSNTC").mean(dim=("lon")).mean(dim='time')

zonalFSNTC_e04=weighted_temporal_mean(FSNTC_e4[0].sel(time=slice('0012-01', '0016-12')),"FSNTC").mean(dim=("lon")).mean(dim='time')

(zonalFSNTC_e04-zonalFSNTC_e0).plot(label='ASR(c)',color='red',linestyle='--')


plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('$Wm^{-2}$',fontsize=20)

plt.legend(fontsize=15)

plt.title('TOA radiation anomaly (e04-e0)',fontsize=20)
plt.tick_params(labelsize=20)

# %%
print('e4,cloud water path',ds4.TGCLDLWP[0].where(DataSet_CAM.mask == 1).weighted(np.cos(np.deg2rad(ds4.Q[0].lat))).mean(dim=("lat","lon")).values)
print('e4,cloud water path',ds4.TGCLDLWP[0].where(DataSet_CAM.mask != 1).weighted(np.cos(np.deg2rad(ds4.Q[0].lat))).mean(dim=("lat","lon")).values)

print('e0,cloud water path',ds0.TGCLDLWP[0].where(DataSet_CAM.mask == 1).weighted(np.cos(np.deg2rad(ds4.Q[0].lat))).mean(dim=("lat","lon")).values)
print('e0,cloud water path',ds0.TGCLDLWP[0].where(DataSet_CAM.mask != 1).weighted(np.cos(np.deg2rad(ds4.Q[0].lat))).mean(dim=("lat","lon")).values)
# Out:
# e4,cloud water path 0.0576392405106706
# e4,cloud water path 0.07966712771585416
# e0,cloud water path 0.04469865220053323
# e0,cloud water path 0.07428439923103283

# %%
# TOA energy balance


plt.figure(figsize=(10,8))

# FLNT

zonalFLNT_e0=FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
zonalFLNT_e04=FLNT_e4[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(zonalFLNT_e04-zonalFLNT_e0).plot(label='OLR')



zonalFSNT_e0=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
zonalFSNT_e04=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(zonalFSNT_e04-zonalFSNT_e0).plot(label='ASR')


# # FLNTC
zonalFLNTC_e0=FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
zonalFLNTC_e04=FLNTC_e4[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(zonalFLNTC_e04-zonalFLNTC_e0).plot(label='OLR(c)',linestyle='--',color='blue')


# # FSNTC

zonalFSNTC_e0=FSNTC_circ[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
zonalFSNTC_e04=FSNTC_e4[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
(zonalFSNTC_e04-zonalFSNTC_e0).plot(label='ASR(c)',color='red',linestyle='--')


plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('$Wm^{-2}$',fontsize=20)

plt.legend(fontsize=15)

plt.title('TOA radiation anomaly (e04-e0) April',fontsize=20)
plt.tick_params(labelsize=20)

# %%
# TOA energy balance


plt.figure(figsize=(10,8))

# FLNT

zonalFLNT_e0=FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=5)
zonalFLNT_e04=FLNT_e4[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=5)

(zonalFLNT_e04-zonalFLNT_e0).plot(label='OLR')



zonalFSNT_e0=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=5)
zonalFSNT_e04=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=5)

(zonalFSNT_e04-zonalFSNT_e0).plot(label='ASR')


# # FLNTC
zonalFLNTC_e0=FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=5)
zonalFLNTC_e04=FLNTC_e4[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=5)

(zonalFLNTC_e04-zonalFLNTC_e0).plot(label='OLR(c)',linestyle='--',color='blue')


# # FSNTC

zonalFSNTC_e0=FSNTC_circ[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=5)
zonalFSNTC_e04=FSNTC_e4[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=5)
(zonalFSNTC_e04-zonalFSNTC_e0).plot(label='ASR(c)',color='red',linestyle='--')


plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('$Wm^{-2}$',fontsize=20)

plt.legend(fontsize=15)

plt.title('TOA radiation anomaly (e04-e0) May',fontsize=20)
plt.tick_params(labelsize=20)

# %%
# TOA energy balance


plt.figure(figsize=(10,8))

# FLNT

zonalFLNT_e0=FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=6)
zonalFLNT_e04=FLNT_e4[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=6)

(zonalFLNT_e04-zonalFLNT_e0).plot(label='OLR')



zonalFSNT_e0=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=6)
zonalFSNT_e04=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=6)

(zonalFSNT_e04-zonalFSNT_e0).plot(label='ASR')


# # FLNTC
zonalFLNTC_e0=FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=6)
zonalFLNTC_e04=FLNTC_e4[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=6)

(zonalFLNTC_e04-zonalFLNTC_e0).plot(label='OLR(c)',linestyle='--',color='blue')


# # FSNTC

zonalFSNTC_e0=FSNTC_circ[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=6)
zonalFSNTC_e04=FSNTC_e4[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=6)
(zonalFSNTC_e04-zonalFSNTC_e0).plot(label='ASR(c)',color='red',linestyle='--')


plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('$Wm^{-2}$',fontsize=20)

plt.legend(fontsize=15)

plt.title('TOA radiation anomaly (e04-e0)',fontsize=20)
plt.tick_params(labelsize=20)

# %%
# TOA energy balance


plt.figure(figsize=(10,8))

# FLNT

zonalFLNT_e0=FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
zonalFLNT_e04=FLNT_e4[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)

(zonalFLNT_e04-zonalFLNT_e0).plot(label='OLR')



zonalFSNT_e0=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
zonalFSNT_e04=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)

(zonalFSNT_e04-zonalFSNT_e0).plot(label='ASR')


# # FLNTC
zonalFLNTC_e0=FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
zonalFLNTC_e04=FLNTC_e4[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)

(zonalFLNTC_e04-zonalFLNTC_e0).plot(label='OLR(c)',linestyle='--',color='blue')


# # FSNTC

zonalFSNTC_e0=FSNTC_circ[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
zonalFSNTC_e04=FSNTC_e4[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
(zonalFSNTC_e04-zonalFSNTC_e0).plot(label='ASR(c)',color='red',linestyle='--')


plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('$Wm^{-2}$',fontsize=20)

plt.legend(fontsize=15)

plt.title('TOA radiation anomaly (e04-e0)',fontsize=20)
plt.tick_params(labelsize=20)

# %%
# FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0')

A=FLNT_e4[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=11)

# FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0 C',linestyle=':')

B=FLNTC_e4[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=11)

(A-B).plot()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0')

A=FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=11)

# FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0 C',linestyle=':')

B=FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=11)

(A-B).plot()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0')

A=FLNT_e4[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)


# FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0 C',linestyle=':')

B=FLNTC_e4[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(A-B).plot()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0')

A=FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)


# FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0 C',linestyle=':')

B=FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(A-B).plot()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0')

A=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

# FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0 C',linestyle=':')

B=FSNTC_e4[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(A-B).plot()

plt.ylabel('FSNT-FSNT(c)')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0')

A=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

# FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0 C',linestyle=':')

B=FSNTC_circ[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(A-B).plot()

plt.ylabel('FSNT-FSNT(c)')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
A_circ=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

A=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

B_circ=FSNTC_circ[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
B=FSNTC_e4[0].FSNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

A.plot(label='FSNT e=0.4')
B.plot(label='FSNT(C) e=0.4')

print('In April, Cloud decreases FSNT especially in the southern hemisphere')
# (A-B).plot(label='e=0.4')
# (B_circ-A_circ).plot(label='e=0')
plt.legend()
# Out:
# In April, Cloud decreases FSNT especially in the southern hemisphere

# %%
TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4).plot(label='e0')

TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4).plot(label='e4')

plt.legend()

# %%
# FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='e0')

# FLNT_e4[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4).plot(label='FSNT e4')

FLNTC_e4[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='FSNT(C) e4')

# FLNT_circ[0].FLNT.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4).plot(label='FSNT e0')

FLNTC_circ[0].FLNTC.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10).plot(label='FSNT(C) e0')

plt.legend()

# %%
# plot zonal mean surface temperature

plt.figure(figsize=(10,8))

LWCF_e0=weighted_temporal_mean(LWCF_circ[0].sel(time=slice('0012-01', '0016-12')),"LWCF").mean(dim=("lon")).mean(dim='time')

LWCF_e04=weighted_temporal_mean(LWCF_e4[0].sel(time=slice('0012-01', '0016-12')),"LWCF").mean(dim=("lon")).mean(dim='time')

(LWCF_e04-LWCF_e0).plot(label='zonal mean LWCF anomaly (e04-e0)')

# 
SWCF_e0=weighted_temporal_mean(SWCF_circ[0].sel(time=slice('0012-01', '0016-12')),"SWCF").mean(dim=("lon")).mean(dim='time')

SWCF_e04=weighted_temporal_mean(SWCF_e4[0].sel(time=slice('0012-01', '0016-12')),"SWCF").mean(dim=("lon")).mean(dim='time')

(SWCF_e04-SWCF_e0).plot(label='zonal mean SWCF anomaly (e04-e0)')

plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('W/m2',fontsize=20)

plt.legend(fontsize=20)
plt.tick_params(labelsize=20)



glb_LWCF_e0=weighted_temporal_mean(LWCF_circ[0].sel(time=slice('0012-01', '0016-12')),"LWCF").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_LWCF_e04=weighted_temporal_mean(LWCF_e4[0].sel(time=slice('0012-01', '0016-12')),"LWCF").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_SWCF_e0=weighted_temporal_mean(SWCF_circ[0].sel(time=slice('0012-01', '0016-12')),"SWCF").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_SWCF_e04=weighted_temporal_mean(SWCF_e4[0].sel(time=slice('0012-01', '0016-12')),"SWCF").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values


# print("global mean LWCF anomaly ratio in percent",100*(glb_LWCF_e04-glb_LWCF_e0)/glb_LWCF_e0)

# print("global mean SWCF anomaly ratio in percent",100*(glb_SWCF_e04-glb_SWCF_e0)/glb_SWCF_e0)

print("global mean SWCF e0",glb_SWCF_e0)

print("global mean SWCF e04",glb_SWCF_e04)


print("global mean SWCF e4 -SWCF e0",glb_SWCF_e04-glb_SWCF_e0)

print("global mean LWCF e0",glb_LWCF_e0)

print("global mean LWCF e04",glb_LWCF_e04)

print("global mean LWCF e4-LWCF e0",glb_LWCF_e04-glb_LWCF_e0)
# Out:
# global mean SWCF e0 -48.67455886269181
# global mean SWCF e04 -43.01416244971051
# global mean SWCF e4 -SWCF e0 5.660396412981299
# global mean LWCF e0 22.92260134433774
# global mean LWCF e04 22.051735119965354
# global mean LWCF e4-LWCF e0 -0.870866224372385

# %%
# plot zonal mean surface temperature

plt.figure(figsize=(10,8))

LWCF_e0=LWCF_circ[0].LWCF.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
LWCF_e04=LWCF_e4[0].LWCF.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(LWCF_e04-LWCF_e0).plot(label='zonal mean LWCF anomaly (e04-e0)')

# 
SWCF_e0=SWCF_circ[0].SWCF.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
SWCF_e04=SWCF_e4[0].SWCF.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(SWCF_e04-SWCF_e0).plot(label='zonal mean SWCF anomaly (e04-e0)')

plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('W/m2',fontsize=20)

plt.legend(fontsize=20)
plt.tick_params(labelsize=20)



# glb_LWCF_e0=weighted_temporal_mean(LWCF_circ[0].sel(time=slice('0012-01', '0016-12')),"LWCF").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

# glb_LWCF_e04=weighted_temporal_mean(LWCF_e4[0].sel(time=slice('0012-01', '0016-12')),"LWCF").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

# glb_SWCF_e0=weighted_temporal_mean(SWCF_circ[0].sel(time=slice('0012-01', '0016-12')),"SWCF").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

# glb_SWCF_e04=weighted_temporal_mean(SWCF_e4[0].sel(time=slice('0012-01', '0016-12')),"SWCF").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values


# print("global mean LWCF anomaly ratio in percent",100*(glb_LWCF_e04-glb_LWCF_e0)/glb_LWCF_e0)

# print("global mean SWCF anomaly ratio in percent",100*(glb_SWCF_e04-glb_SWCF_e0)/glb_SWCF_e0)

print("global mean SWCF e0",glb_SWCF_e0)

print("global mean SWCF e04",glb_SWCF_e04)


print("global mean SWCF e4 -SWCF e0",glb_SWCF_e04-glb_SWCF_e0)

print("global mean LWCF e0",glb_LWCF_e0)

print("global mean LWCF e04",glb_LWCF_e04)

print("global mean LWCF e4-LWCF e0",glb_LWCF_e04-glb_LWCF_e0)
# Out:
# global mean SWCF e0 -48.67455886269181
# global mean SWCF e04 -43.01416244971051
# global mean SWCF e4 -SWCF e0 5.660396412981299
# global mean LWCF e0 22.92260134433774
# global mean LWCF e04 22.051735119965354
# global mean LWCF e4-LWCF e0 -0.870866224372385

# %%
plt.figure()

TS_e0=TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
TS_e04=TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
(TS_e04).plot(label='zonal mean TS anomaly (e04-e0)')
(TS_e0).plot(label='zonal mean TS anomaly (e04-e0)')

plt.figure()
(TS_e04-TS_e0).plot(label='zonal mean TS anomaly (e04-e0)')
plt.figure()

TS_e0=TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=11)
TS_e04=TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=11)
(TS_e04).plot(label='zonal mean TS anomaly (e04-e0)')
(TS_e0).plot(label='zonal mean TS anomaly (e04-e0)')

plt.figure()
(TS_e04-TS_e0).plot(label='zonal mean TS anomaly (e04-e0)')
plt.figure()

CLDLOW_e0=CLDLOW_circ[0].CLDLOW.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
CLDLOW_e04=CLDLOW_e4[0].CLDLOW.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
(CLDLOW_e04).plot(label='zonal mean TS anomaly (e04-e0)')
(CLDLOW_e0).plot(label='zonal mean TS anomaly (e04-e0)')

plt.figure()
(CLDLOW_e04-CLDLOW_e0).plot(label='zonal mean TS anomaly (e04-e0)')

# 

plt.figure()

CLDHGH_e0=CLDHGH_circ[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
CLDHGH_e04=CLDHGH_e4[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=10)
(CLDHGH_e04).plot(label='zonal mean TS anomaly (e04-e0)')
(CLDHGH_e0).plot(label='zonal mean TS anomaly (e04-e0)')

plt.figure()
(CLDHGH_e04-CLDHGH_e0).plot(label='zonal mean TS anomaly (e04-e0)')

# plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

# # plt.ylabel('W/m2',fontsize=20)

# plt.legend(fontsize=20)
plt.tick_params(labelsize=20)

# %%
plt.figure()

CLDHGH_e0=CLDHGH_circ[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
CLDHGH_e04=CLDHGH_e4[0].CLDHGH.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
(CLDHGH_e04).plot(label='zonal mean TS anomaly (e04-e0)')
(CLDHGH_e0).plot(label='zonal mean TS anomaly (e04-e0)')

plt.figure()
(CLDHGH_e04-CLDHGH_e0).plot(label='zonal mean TS anomaly (e04-e0)')

# %%
SWCF_e0=SWCF_circ[0].SWCF.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)
SWCF_e04=SWCF_e4[0].SWCF.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time').sel(month=4)

(SWCF_e04-SWCF_e0).plot(label='zonal mean SWCF anomaly (e04-e0)')

# %%
#
glb_FLNT_e0=weighted_temporal_mean(FLNT_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_FLNTC_e0=weighted_temporal_mean(FLNTC_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNTC").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_FSNT_e0=weighted_temporal_mean(FSNT_circ[0].sel(time=slice('0012-01', '0016-12')),"FSNT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_FSNTC_e0=weighted_temporal_mean(FSNTC_circ[0].sel(time=slice('0012-01', '0016-12')),"FSNTC").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
#
glb_FLNT_e4=weighted_temporal_mean(FLNT_e4[0].sel(time=slice('0010-01', '0014-12')),"FLNT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_FLNTC_e4=weighted_temporal_mean(FLNTC_e4[0].sel(time=slice('0010-01', '0014-12')),"FLNTC").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_FSNT_e4=weighted_temporal_mean(FSNT_e4[0].sel(time=slice('0010-01', '0014-12')),"FSNT").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_FSNTC_e4=weighted_temporal_mean(FSNTC_e4[0].sel(time=slice('0010-01', '0014-12')),"FSNTC").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

print('global mean FLNT anomaly ratio in percentage',100*(glb_FLNT_e4-glb_FLNT_e0)/glb_FLNT_e0)

print('global mean FSNT anomaly ratio in percentage',100*(glb_FSNT_e4-glb_FSNT_e0)/glb_FSNT_e0)

print('global mean FLNTC anomaly ratio in percentage',100*(glb_FLNTC_e4-glb_FLNTC_e0)/glb_FLNTC_e0)

print('global mean FSNTC anomaly ratio in percentage',100*(glb_FSNTC_e4-glb_FSNTC_e0)/glb_FSNTC_e0)

print('global mean FSNT,e=0.4',glb_FSNT_e4)
print('global mean FSNT,e=0',glb_FSNT_e0)


print('global mean FLNT,e=0.4',glb_FLNT_e4)
print('global mean FLNT,e=0',glb_FLNT_e0)
# Out:
# global mean FLNT anomaly ratio in percentage 1.7860950026361286
# global mean FSNT anomaly ratio in percentage 2.548540564691078
# global mean FLNTC anomaly ratio in percentage 1.307512321822478
# global mean FSNTC anomaly ratio in percentage 0.10436044679942444
# global mean FSNT,e=0.4 243.94126775882086
# global mean FSNT,e=0 237.87882929931556
# global mean FLNT,e=0.4 244.71196085747988
# global mean FLNT,e=0 240.41786930831972

# %%
# TOA energy balance


plt.figure(figsize=(10,8))

# FLNS

zonalFLNS_e0=weighted_temporal_mean(FLNS_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNS").mean(dim=("lon")).mean(dim='time')

zonalFLNS_e04=weighted_temporal_mean(FLNS_e4[0].sel(time=slice('0010-01', '0014-12')),"FLNS").mean(dim=("lon")).mean(dim='time')

(zonalFLNS_e04-zonalFLNS_e0).plot(label='LW')

# FSNS

zonalFSNS_e0=weighted_temporal_mean(FSNS_circ[0].sel(time=slice('0012-01', '0016-12')),"FSNS").mean(dim=("lon")).mean(dim='time')

zonalFSNS_e04=weighted_temporal_mean(FSNS_e4[0].sel(time=slice('0010-01', '0014-12')),"FSNS").mean(dim=("lon")).mean(dim='time')

(zonalFSNS_e04-zonalFSNS_e0).plot(label='SW',color='red')


# FLNSC

zonalFLNSC_e0=weighted_temporal_mean(FLNSC_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNSC").mean(dim=("lon")).mean(dim='time')

zonalFLNSC_e04=weighted_temporal_mean(FLNSC_e4[0].sel(time=slice('0010-01', '0014-12')),"FLNSC").mean(dim=("lon")).mean(dim='time')

(zonalFLNSC_e04-zonalFLNSC_e0).plot(label='LW(c)',linestyle='--',color='blue')


# FSNSC

zonalFSNSC_e0=weighted_temporal_mean(FSNSC_circ[0].sel(time=slice('0012-01', '0016-12')),"FSNSC").mean(dim=("lon")).mean(dim='time')

zonalFSNSC_e04=weighted_temporal_mean(FSNSC_e4[0].sel(time=slice('0010-01', '0014-12')),"FSNSC").mean(dim=("lon")).mean(dim='time')

(zonalFSNSC_e04-zonalFSNSC_e0).plot(label='SW(c)',color='red',linestyle='--')


plt.xlabel('latitude ($^{\circ}$)',fontsize=20)

plt.ylabel('$Wm^{-2}$',fontsize=20)

plt.legend(fontsize=15)

plt.title('Surface radiation anomaly (e04-e0)',fontsize=20)
plt.tick_params(labelsize=20)

#

# glbFLNS_e0=weighted_temporal_mean(FLNS_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNS").mean(dim=("lon")).mean(dim='time')

# glbFLNS_e04=weighted_temporal_mean(FLNS_e4[0].sel(time=slice('0010-01', '0014-12')),"FLNS").mean(dim=("lon")).mean(dim='time')

# (zonalFLNS_e04-zonalFLNS_e0).plot(label='LW')

# %%
#
glb_FLNS_e0=weighted_temporal_mean(FLNS_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNS").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
glb_FLNSC_e0=weighted_temporal_mean(FLNSC_circ[0].sel(time=slice('0012-01', '0016-12')),"FLNSC").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_FSNS_e0=weighted_temporal_mean(FSNS_circ[0].sel(time=slice('0012-01', '0016-12')),"FSNS").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
glb_FSNSC_e0=weighted_temporal_mean(FSNSC_circ[0].sel(time=slice('0012-01', '0016-12')),"FSNSC").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
#
glb_FLNS_e4=weighted_temporal_mean(FLNS_e4[0].sel(time=slice('0012-01', '0016-12')),"FLNS").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
glb_FLNSC_e4=weighted_temporal_mean(FLNSC_e4[0].sel(time=slice('0012-01', '0016-12')),"FLNSC").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

glb_FSNS_e4=weighted_temporal_mean(FSNS_e4[0].sel(time=slice('0012-01', '0016-12')),"FSNS").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values
glb_FSNSC_e4=weighted_temporal_mean(FSNSC_e4[0].sel(time=slice('0012-01', '0016-12')),"FSNSC").weighted(np.cos(np.deg2rad(TS_circ[0].TS.lat))).mean(dim=("lat","lon")).mean(dim='time').values

print('global mean FLNS anomaly ratio in percentage',100*(glb_FLNS_e4-glb_FLNS_e0)/glb_FLNS_e0)

print('global mean FSNS anomaly ratio in percentage',100*(glb_FSNS_e4-glb_FSNS_e0)/glb_FSNS_e0)

print('global mean FLNSC anomaly ratio in percentage',100*(glb_FLNSC_e4-glb_FLNSC_e0)/glb_FLNSC_e0)

print('global mean FSNSC anomaly ratio in percentage',100*(glb_FSNSC_e4-glb_FSNSC_e0)/glb_FSNSC_e0)
# Out:
# global mean FLNS anomaly ratio in percentage -7.117175132941879
# global mean FSNS anomaly ratio in percentage 0.0
# global mean FLNSC anomaly ratio in percentage -6.3607437852160995
# global mean FSNSC anomaly ratio in percentage 0.0

# %%
weights=np.cos(np.deg2rad(TS_circ[0].TS.lat))

TS_trop_e0=TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').where((ds4.lat > -23.5 ) & (ds4.lat < 23.5)).weighted(weights).mean(dim=("lat","lon"))

TS_trop_e4=TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').where((ds4.lat > -23.5 ) & (ds4.lat < 23.5)).weighted(weights).mean(dim=("lat","lon"))

TS_NP_e0=TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').where(ds4.lat > 75 ).weighted(weights).mean(dim=("lat","lon"))

TS_NP_e4=TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').where(ds4.lat > 75 ).weighted(weights).mean(dim=("lat","lon"))

TS_SP_e0=TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').where(ds4.lat < -75 ).weighted(weights).mean(dim=("lat","lon"))

TS_SP_e4=TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').where(ds4.lat < -75 ).weighted(weights).mean(dim=("lat","lon"))
TS_e0_mean=TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(weights).mean(dim=("lat","lon"))

TS_e4_mean=TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(weights).mean(dim=("lat","lon"))


(TS_trop_e0-TS_NP_e0).plot(label='trop-np e0')

(TS_trop_e0-TS_SP_e0).plot(label='trop-sp e0')

plt.legend()

plt.figure()

(TS_trop_e4-TS_NP_e4).plot(label='trop-np e4')

(TS_trop_e4-TS_SP_e4).plot(label='trop-sp e4')

plt.legend()

# %%
plt.plot(TS_trop_e4.values,(TS_trop_e4-TS_NP_e4).values,label='e=0.4, tropics-north pole')

plt.plot(TS_trop_e0.values,(TS_trop_e0-TS_NP_e0).values,label='e=0, tropics-north pole')

plt.legend()
plt.figure()

plt.plot(TS_trop_e4.values,(TS_trop_e4-TS_SP_e4).values,label='e=0.4, tropics-south pole')

plt.plot(TS_trop_e0.values,(TS_trop_e0-TS_SP_e0).values,label='e=0, tropics-south pole')

plt.figure()


normalized_delta_T_e0=(((TS_trop_e0-TS_NP_e0)+(TS_trop_e0-TS_SP_e0))/2).values/TS_e0_mean.values

normalized_delta_T_e4=(((TS_trop_e4-TS_NP_e4)+(TS_trop_e4-TS_SP_e4))/2).values/TS_e4_mean.values

plt.plot(TS_trop_e4.values,normalized_delta_T_e4,label='e=0.4',linestyle='--', marker='o',color='b')

plt.plot(TS_trop_e4.values[0], normalized_delta_T_e4[0], 'go',label='January, e=0.4')
plt.plot(TS_trop_e4.values[-1],normalized_delta_T_e4[-1], 'ro',label='December, e=0.4')


plt.plot([TS_trop_e4.values[0],TS_trop_e4.values[-1]],[normalized_delta_T_e4[0],normalized_delta_T_e4[-1]], 'b--')

plt.plot(TS_trop_e0.values,normalized_delta_T_e0,label='e=0', linestyle="None",marker='.',color='orange')

plt.plot(TS_trop_e0.values[2], normalized_delta_T_e0[2], color='black',marker='*',label='March, e=0')
plt.plot(TS_trop_e0.values[8],normalized_delta_T_e0[8], color='purple',marker='*',label='August, e=0')

plt.xlabel('Max(TS) (K)')

plt.ylabel('Normalized $\Delta$ T')

plt.legend()

# %%
plt.figure()

normalized_delta_T_e0=(((TS_trop_e0-TS_NP_e0)+(TS_trop_e0-TS_SP_e0))/2).values

normalized_delta_T_e4=(((TS_trop_e4-TS_NP_e4)+(TS_trop_e4-TS_SP_e4))/2).values

plt.plot(TS_trop_e4.values,normalized_delta_T_e4,label='e=0.4',linestyle='--', marker='o',color='b')

plt.plot(TS_trop_e4.values[0], normalized_delta_T_e4[0], 'go',label='January, e=0.4')
plt.plot(TS_trop_e4.values[-1],normalized_delta_T_e4[-1], 'ro',label='December, e=0.4')


plt.plot([TS_trop_e4.values[0],TS_trop_e4.values[-1]],[normalized_delta_T_e4[0],normalized_delta_T_e4[-1]], 'b--')

plt.plot(TS_trop_e0.values,normalized_delta_T_e0,label='e=0', linestyle="None",marker='.',color='orange')

plt.plot(TS_trop_e0.values[2], normalized_delta_T_e0[2], color='black',marker='*',label='March, e=0')
plt.plot(TS_trop_e0.values[8],normalized_delta_T_e0[8], color='purple',marker='*',label='August, e=0')

plt.xlabel('Max(TS) (K)')

plt.ylabel('Normalized $\Delta$ T')

plt.legend()

# %%
ASR_circ=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(weights).mean(dim=("lat","lon"))

ASR_e4=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(weights).mean(dim=("lat","lon"))


plt.plot(ASR_circ.values,TS_trop_e0.values,label='e=0',linestyle='None', marker='o',color='orange')

plt.plot(ASR_e4.values,TS_trop_e4.values,label='e=0.4',linestyle='--', marker='o',color='b')

plt.plot([ASR_e4.values[0],ASR_e4.values[-1]],[TS_trop_e4.values[0],TS_trop_e4.values[-1]],linestyle='--', marker='o',color='b')

plt.plot(ASR_e4.values[0],TS_trop_e4.values[0],'go',label='January, e=0.4')

plt.plot(ASR_e4.values[-1],TS_trop_e4.values[-1],'ro',label='December, e=0.4')

plt.ylabel('Max(TS) (K)')

plt.xlabel('FSNT (W/m2)')


plt.legend()

# %%
ASR_circ=FSNT_circ[0].FSNT.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(weights).mean(dim=("lat","lon"))

ASR_e4=FSNT_e4[0].FSNT.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(weights).mean(dim=("lat","lon"))


SOLIN_e0_glb=SOLIN_circ[0].SOLIN.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(weights).mean(dim=("lat","lon"))

SOLIN_e4_glb=SOLIN_e4[0].SOLIN.sel(time=slice('0012-01', '0016-12')).groupby('time.month').mean(dim='time').weighted(weights).mean(dim=("lat","lon"))

plt.plot(ASR_circ.values,SOLIN_e0_glb.values,label='e=0',linestyle='None', marker='o',color='orange')

plt.plot(ASR_e4.values,SOLIN_e4_glb.values,label='e=0.4',linestyle='--', marker='o',color='b')

plt.plot([ASR_e4.values[0],ASR_e4.values[-1]],[SOLIN_e4_glb.values[0],SOLIN_e4_glb.values[-1]],linestyle='--', marker='o',color='b')

plt.plot(ASR_e4.values[0],SOLIN_e4_glb.values[0],'go',label='January, e=0.4')

plt.plot(ASR_e4.values[-1],SOLIN_e4_glb.values[-1],'ro',label='December, e=0.4')

plt.ylabel('SOLIN (W/m2)')

plt.xlabel('FSNT (W/m2)')


plt.legend()

# %%
SOLIN_e4_glb.plot()
ASR_e4.plot()

# %%
SOLIN_e4_glb

# %%
plt.figure(figsize=(10,8))

zonalTS_e0=TS_circ[0].TS.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time')

zonalTS_e4=TS_e4[0].TS.sel(time=slice('0012-01', '0016-12')).mean(dim=("lon")).groupby('time.month').mean(dim='time')

# %%
(zonalTS_e4).plot(x='month')
