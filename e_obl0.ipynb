# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr


# define eccentricity range

e_range =['e0','e01','e02','e03','e04']

# define path 

data_dir_file = []

for i in range(len(e_range)):
    data_dir_file.append('/nobackup/pybl/cesm2/archive/b.e21.BWma1850.f19_g17.'+ e_range[i]+'_obl0.001/atm/hist/')


# define specific path

Path_TS        = []
Path_ICEFRAC   = []
Path_FSNT      = []
Path_FSUTOA    = []
Path_U         = []

for i in range(len(data_dir_file)):
    Path_TS.append(data_dir_file[i]+'TS_'+ e_range[i] +'_obl0.nc')
    Path_ICEFRAC.append(data_dir_file[i]+'ICEFRAC_'+ e_range[i] +'_obl0.nc')
    Path_FSNT.append(data_dir_file[i]+'FSNT_'+ e_range[i] +'_obl0.nc')
    Path_FSUTOA.append(data_dir_file[i]+'FSUTOA_'+ e_range[i] +'_obl0.nc')
    Path_U.append(data_dir_file[i]+'U_'+ e_range[i] +'_obl0.nc')



# Import data

# TS

TS_e0_obl0  = xr.open_mfdataset(Path_TS[0],decode_times=False)
TS_e01_obl0 = xr.open_mfdataset(Path_TS[1],decode_times=False)
TS_e02_obl0 = xr.open_mfdataset(Path_TS[2],decode_times=False)
TS_e03_obl0 = xr.open_mfdataset(Path_TS[3],decode_times=False)
TS_e04_obl0 = xr.open_mfdataset(Path_TS[4],decode_times=False)

# ICEFRAC
ICEFRAC_e0_obl0  = xr.open_mfdataset(Path_ICEFRAC[0],decode_times=False)
ICEFRAC_e01_obl0 = xr.open_mfdataset(Path_ICEFRAC[1],decode_times=False)
ICEFRAC_e02_obl0 = xr.open_mfdataset(Path_ICEFRAC[2],decode_times=False)
ICEFRAC_e03_obl0 = xr.open_mfdataset(Path_ICEFRAC[3],decode_times=False)
ICEFRAC_e04_obl0 = xr.open_mfdataset(Path_ICEFRAC[4],decode_times=False)

# FSNT
FSNT_e0_obl0  = xr.open_mfdataset(Path_FSNT[0],decode_times=False)
FSNT_e01_obl0 = xr.open_mfdataset(Path_FSNT[1],decode_times=False)
FSNT_e02_obl0 = xr.open_mfdataset(Path_FSNT[2],decode_times=False)
FSNT_e03_obl0 = xr.open_mfdataset(Path_FSNT[3],decode_times=False)
FSNT_e04_obl0 = xr.open_mfdataset(Path_FSNT[4],decode_times=False)

# FSUTOA
FSUTOA_e0_obl0  = xr.open_mfdataset(Path_FSUTOA[0],decode_times=False)
FSUTOA_e01_obl0 = xr.open_mfdataset(Path_FSUTOA[1],decode_times=False)
FSUTOA_e02_obl0 = xr.open_mfdataset(Path_FSUTOA[2],decode_times=False)
FSUTOA_e03_obl0 = xr.open_mfdataset(Path_FSUTOA[3],decode_times=False)
FSUTOA_e04_obl0 = xr.open_mfdataset(Path_FSUTOA[4],decode_times=False)

# U
U_e0_obl0  = xr.open_mfdataset(Path_U[0],decode_times=False)
U_e01_obl0 = xr.open_mfdataset(Path_U[1],decode_times=False)
U_e02_obl0 = xr.open_mfdataset(Path_U[2],decode_times=False)
U_e03_obl0 = xr.open_mfdataset(Path_U[3],decode_times=False)
U_e04_obl0 = xr.open_mfdataset(Path_U[4],decode_times=False)

# Slice the data for upto 1 year (or 12 months)

Number_years =int(12*1-1)

# TS
TS_e0_obl0  = TS_e0_obl0.TS[:Number_years,:,:] 
TS_e01_obl0 = TS_e01_obl0.TS[:Number_years,:,:] 
TS_e02_obl0 = TS_e02_obl0.TS[:Number_years,:,:] 
TS_e03_obl0 = TS_e03_obl0.TS[:Number_years,:,:] 
TS_e04_obl0 = TS_e04_obl0.TS[:Number_years,:,:] 

# ICEFRAC
ICEFRAC_e0_obl0  = ICEFRAC_e0_obl0.ICEFRAC[:Number_years,:,:] 
ICEFRAC_e01_obl0 = ICEFRAC_e01_obl0.ICEFRAC[:Number_years,:,:] 
ICEFRAC_e02_obl0 = ICEFRAC_e02_obl0.ICEFRAC[:Number_years,:,:] 
ICEFRAC_e03_obl0 = ICEFRAC_e03_obl0.ICEFRAC[:Number_years,:,:] 
ICEFRAC_e04_obl0 = ICEFRAC_e04_obl0.ICEFRAC[:Number_years,:,:] 

# FSNT 
FSNT_e0_obl0  = FSNT_e0_obl0.FSNT[:Number_years,:,:] 
FSNT_e01_obl0 = FSNT_e01_obl0.FSNT[:Number_years,:,:] 
FSNT_e02_obl0 = FSNT_e02_obl0.FSNT[:Number_years,:,:] 
FSNT_e03_obl0 = FSNT_e03_obl0.FSNT[:Number_years,:,:] 
FSNT_e04_obl0 = FSNT_e04_obl0.FSNT[:Number_years,:,:] 


# FSUTOA
FSUTOA_e0_obl0  = FSUTOA_e0_obl0.FSUTOA[:Number_years,:,:] 
FSUTOA_e01_obl0 = FSUTOA_e01_obl0.FSUTOA[:Number_years,:,:] 
FSUTOA_e02_obl0 = FSUTOA_e02_obl0.FSUTOA[:Number_years,:,:] 
FSUTOA_e03_obl0 = FSUTOA_e03_obl0.FSUTOA[:Number_years,:,:] 
FSUTOA_e04_obl0 = FSUTOA_e04_obl0.FSUTOA[:Number_years,:,:]

# U
U_e0_obl0  = U_e0_obl0.U[:Number_years,:,:] 
U_e01_obl0 = U_e01_obl0.U[:Number_years,:,:] 
U_e02_obl0 = U_e02_obl0.U[:Number_years,:,:] 
U_e03_obl0 = U_e03_obl0.U[:Number_years,:,:] 
U_e04_obl0 = U_e04_obl0.U[:Number_years,:,:]

# %%
# Define the global weighting function

print('define LatWeightAnyVar')

File_h0 = "/nobackup/pybl/cesm2/archive/b.e21.BWma1850.f19_g17.e0_obl0.001/atm/hist/b.e21.BWma1850.f19_g17.e0_obl0.001.cam.h0.0001-03.nc" #file name

DataSet_h0 = xr.open_dataset(File_h0,decode_times=False) 

gw = DataSet_h0.gw.values

Pressure = DataSet_h0.lev.values

def LatWeightAnyVar(DS, time = False):
    try:
        DS = DS.mean(dim='lon')         # take longitudinal mean
    except:
        print('')
    if (time == False):
        try:
            DS = DS.mean(dim='time')    # take time mean
        except:
            print('')
    DS = gw*DS                          # multiply by gaussian weights
    try:
        DS = np.sum(DS,axis=1)/gw.sum() # weighted mean
    except:
        DS = np.sum(DS,axis=0)/gw.sum() # weighted mean 
    return DS                           # return a numpy array that has been modified above
# Out:
# define LatWeightAnyVar

# %%
global_FSUTOA_e0_obl0=[]

for i in range(len(FSUTOA_e0_obl0)):
    global_FSUTOA_e0_obl0.append(LatWeightAnyVar(FSUTOA_e0_obl0[i]))
    
global_FSNT_e0_obl0=[]

for i in range(len(FSNT_e0_obl0)):
    global_FSNT_e0_obl0.append(LatWeightAnyVar(FSNT_e0_obl0[i]))
    
albedo_e0_obl0=[]

for i in range(len(FSNT_e0_obl0)):
    albedo_e0_obl0.append(global_FSUTOA_e0_obl0[i]/global_FSNT_e0_obl0[i])
    
# repeat for e01

global_FSUTOA_e01_obl0=[]

for i in range(len(FSUTOA_e01_obl0)):
    global_FSUTOA_e01_obl0.append(LatWeightAnyVar(FSUTOA_e01_obl0[i]))
    
global_FSNT_e01_obl0=[]

for i in range(len(FSNT_e01_obl0)):
    global_FSNT_e01_obl0.append(LatWeightAnyVar(FSNT_e01_obl0[i]))
    
albedo_e01_obl0=[]

for i in range(len(FSNT_e01_obl0)):
    albedo_e01_obl0.append(global_FSUTOA_e01_obl0[i]/global_FSNT_e01_obl0[i])
    
# repeat for e02

global_FSUTOA_e02_obl0=[]

for i in range(len(FSUTOA_e02_obl0)):
    global_FSUTOA_e02_obl0.append(LatWeightAnyVar(FSUTOA_e02_obl0[i]))
    
global_FSNT_e02_obl0=[]

for i in range(len(FSNT_e02_obl0)):
    global_FSNT_e02_obl0.append(LatWeightAnyVar(FSNT_e02_obl0[i]))
    
albedo_e02_obl0=[]

for i in range(len(FSNT_e02_obl0)):
    albedo_e02_obl0.append(global_FSUTOA_e02_obl0[i]/global_FSNT_e02_obl0[i])
    
# repeat for e03

global_FSUTOA_e03_obl0=[]

for i in range(len(FSUTOA_e03_obl0)):
    global_FSUTOA_e03_obl0.append(LatWeightAnyVar(FSUTOA_e03_obl0[i]))
    
global_FSNT_e03_obl0=[]

for i in range(len(FSNT_e03_obl0)):
    global_FSNT_e03_obl0.append(LatWeightAnyVar(FSNT_e03_obl0[i]))
    
albedo_e03_obl0=[]

for i in range(len(FSNT_e03_obl0)):
    albedo_e03_obl0.append(global_FSUTOA_e03_obl0[i]/global_FSNT_e03_obl0[i])
    
plt.plot(albedo_e0_obl0,'r',label='e=0')
plt.plot(albedo_e01_obl0,'k',label='e=0.1')
plt.plot(albedo_e02_obl0,'g',label='e=0.2')
plt.plot(albedo_e03_obl0,'b',label='e=0.3')
plt.legend()
plt.title('Bond Albedo for Zero-Obliquity Cases')
plt.xlabel('Months')
plt.ylabel('Albedo (FSUTOA/FSNT)')
plt.show()

# %%
# For the e0 case:

global_TS_e0=[]

for i in range(len(TS_1yre0)):
    global_TS_e0.append(LatWeightAnyVar(TS_1yre0[i]))
    
annual_mean_global_TS_e0=[np.mean(global_TS_e0[0:12]),
                               np.mean(global_TS_e0[12:24]),
                               np.mean(global_TS_e0[24:36]),
                               np.mean(global_TS_e0[36:48]),
                               np.mean(global_TS_e0[48:60]),
                               np.mean(global_TS_e0[60:72]),
                               np.mean(global_TS_e0[72:84]),
                               np.mean(global_TS_e0[84:96])]

years=list(range(1,9))

diff_e0=[np.abs(i- np.mean(annual_mean_global_TS_e0)) for i in annual_mean_global_TS_e0]

fig, ax1 = plt.subplots(figsize=(8,6))
    
ax1t = ax1.twinx()

ax1.plot(years,annual_mean_global_TS_e0,'b-',label='TS')
ax1.plot((1, 8), (np.mean(annual_mean_global_TS_e0), np.mean(annual_mean_global_TS_e0)), 'k--',label='8-year average TS')

ax1t.plot(years,diff_e0,'r',label='|TS-$\overline{TS}$|')

ax1.set_xlabel('Year')
ax1.set_ylabel('Temperature in Kelvin')
ax1.legend()
ax1t.legend()

ax1t.set_ylim([0,1])
plt.title("The Annual Mean Global Surface Temperature for Default $e$",fontsize=10)
plt.show()

# %%
global_ICEFRAC_e0_obl0=[]

for i in range(len(ICEFRAC_e0_obl0)):
    global_ICEFRAC_e0_obl0.append(LatWeightAnyVar(ICEFRAC_e0_obl0[i]))
    
# repeat for e01

global_ICEFRAC_e01_obl0=[]

for i in range(len(ICEFRAC_e01_obl0)):
    global_ICEFRAC_e01_obl0.append(LatWeightAnyVar(ICEFRAC_e01_obl0[i]))
    
# repeat for e02

global_ICEFRAC_e02_obl0=[]

for i in range(len(ICEFRAC_e02_obl0)):
    global_ICEFRAC_e02_obl0.append(LatWeightAnyVar(ICEFRAC_e02_obl0[i]))
    
# repeat for e03

global_ICEFRAC_e03_obl0=[]

for i in range(len(ICEFRAC_e03_obl0)):
    global_ICEFRAC_e03_obl0.append(LatWeightAnyVar(ICEFRAC_e03_obl0[i]))
    
    
plt.plot(global_ICEFRAC_e0_obl0,'r',label='e=0')
plt.plot(global_ICEFRAC_e01_obl0,'k',label='e=0.1')
plt.plot(global_ICEFRAC_e02_obl0,'g',label='e=0.2')
plt.plot(global_ICEFRAC_e03_obl0,'b',label='e=0.3')
plt.legend()
plt.title('Global ICEFRAC for Zero-Obliquity Cases')
plt.xlabel('Months')
plt.ylabel('Percentage')
plt.show()

# %%
global_TS_e0_obl0=[]

for i in range(len(TS_e0_obl0)):
    global_TS_e0_obl0.append(LatWeightAnyVar(TS_e0_obl0[i]))
    
# repeat for e01

global_TS_e01_obl0=[]

for i in range(len(TS_e01_obl0)):
    global_TS_e01_obl0.append(LatWeightAnyVar(TS_e01_obl0[i]))
    
# repeat for e02

global_TS_e02_obl0=[]

for i in range(len(TS_e02_obl0)):
    global_TS_e02_obl0.append(LatWeightAnyVar(TS_e02_obl0[i]))
# repeat for e03

global_TS_e03_obl0=[]

for i in range(len(TS_e03_obl0)):
    global_TS_e03_obl0.append(LatWeightAnyVar(TS_e03_obl0[i]))
    
    
plt.plot(global_TS_e0_obl0,'r',label='e=0')
plt.plot(global_TS_e01_obl0,'k',label='e=0.1')
plt.plot(global_TS_e02_obl0,'g',label='e=0.2')
plt.plot(global_TS_e03_obl0,'b',label='e=0.3')
plt.legend()
plt.title('Global Surface Temperature for Zero-Obliquity Cases')
plt.xlabel('Months')
plt.ylabel('K')
plt.show()

# %%
global_FSNT_e0_obl0=[]

for i in range(len(FSNT_e0_obl0)):
    global_FSNT_e0_obl0.append(LatWeightAnyVar(FSNT_e0_obl0[i]))
    
# repeat for e01

global_FSNT_e01_obl0=[]

for i in range(len(FSNT_e01_obl0)):
    global_FSNT_e01_obl0.append(LatWeightAnyVar(FSNT_e01_obl0[i]))
    
# repeat for e02

global_FSNT_e02_obl0=[]

for i in range(len(FSNT_e02_obl0)):
    global_FSNT_e02_obl0.append(LatWeightAnyVar(FSNT_e02_obl0[i]))
    
# repeat for e03
global_FSNT_e03_obl0=[]

for i in range(len(FSNT_e03_obl0)):
    global_FSNT_e03_obl0.append(LatWeightAnyVar(FSNT_e03_obl0[i]))
    
plt.plot(global_FSNT_e0_obl0,'r',label='e=0')
plt.plot(global_FSNT_e01_obl0,'k',label='e=0.1')
plt.plot(global_FSNT_e02_obl0,'g',label='e=0.2')
plt.plot(global_FSNT_e03_obl0,'b',label='e=0.3')
plt.legend()
plt.title('Incident Flux for Zero-Obliquity Cases')
plt.xlabel('Months')
plt.ylabel('W/m^2')
plt.show()

# %%
FSNT_e0_obl0
# Out:
# <xarray.DataArray 'FSNT' (time: 11, lat: 96, lon: 144)>
# dask.array<getitem, shape=(11, 96, 144), dtype=float32, chunksize=(11, 96, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 84.32 86.21 88.11 90.0
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) float64 90.0 120.0 151.0 181.0 ... 304.0 334.0 365.0 396.0
# Attributes:
#     Sampling_Sequence:  rad_lwsw
#     units:              W/m2
#     long_name:          Net solar flux at top of model
#     cell_methods:       time: mean

# %%
# extract ozone zonal mean: averaged along longitude

U = U_e0_obl0.mean(dim='lon').isel(time=0) 

## now each U data point associated with coords latitude and leviation

## where lev has units :hPa, is atmosphere_hybrid_sigma_pressure_coordinate

# create a contour plot 
plt.figure(figsize=(12,8))

U.plot.pcolormesh()

#control the look of the output
ax = plt.gca()

ax.set_ylim([1000,0.1])
ax.set_yscale('log')
ax.set_ylabel('Pressure (hPa)')
plt.title('U m/s')
plt.show()


# # create a vertical plot 
# plt.figure(figsize=(12,8))

# #control the look of the output
# ax1 = plt.gca()

# ax1.set_ylim([1000,0.0001])
# ax1.set_yscale('log')
# ax1.set_ylabel('Pressure (hPa)')
# nlev = ds['lev']
# plt.plot(U,nlev)


# plt.title('This is not correct because you need Gaussain weights over latitude')
# print(np.size(nlev))
# plt.show()

# %%
# extract ozone zonal mean: averaged along longitude

TS = TS_e0_obl0.mean(dim='lon').isel(time=0) 
TS_e01 = TS_e01_obl0.mean(dim='lon').isel(time=0) 
TS_e02 = TS_e02_obl0.mean(dim='lon').isel(time=0) 
TS_e03 = TS_e03_obl0.mean(dim='lon').isel(time=0) 

## now each U data point associated with coords latitude and leviation

## where lev has units :hPa, is atmosphere_hybrid_sigma_pressure_coordinate

# create a contour plot 
plt.figure(figsize=(12,8))

TS.plot()

TS_e01.plot()

TS_e02.plot()

TS_e03.plot()

#control the look of the output
ax = plt.gca()

plt.title('TS vs Latitude')
plt.show()

# %%
# For the e02_obl0 case:

global_TS_e02_obl0=[]

for i in range(len(TS_branch_1yre02_obl0)):
    global_TS_e02_obl0.append(LatWeightAnyVar(TS_branch_1yre02_obl0[i]))
    
annual_mean_global_TS_e02_obl0=[np.mean(global_TS_e02_obl0[0:12]),
                               np.mean(global_TS_e02_obl0[12:24]),
                               np.mean(global_TS_e02_obl0[24:36]),
                               np.mean(global_TS_e02_obl0[36:48]),
                               np.mean(global_TS_e02_obl0[48:60])]

print(annual_mean_global_TS_e02_obl0)

years=list(range(1,6))


diff_e02_obl0=[np.abs(i- np.mean(annual_mean_global_TS_e02_obl0)) for i in annual_mean_global_TS_e02_obl0]

fig, ax1 = plt.subplots(figsize=(8,6))
    
ax1t = ax1.twinx()

ax1.plot(years,annual_mean_global_TS_e02_obl0,'b-',label='TS')

ax1.plot((1, 5), (np.mean(annual_mean_global_TS_e02_obl0), np.mean(annual_mean_global_TS_e02_obl0)), 'k--',label='5-year average TS')

ax1t.plot(years,diff_e02_obl0,'r',label='|TS-$\overline{TS}$|')

ax1.set_xlabel('Year')
ax1.set_ylabel('Temperature in Kelvin')
ax1.legend()
ax1t.legend()

ax1t.set_ylim([0,2])
plt.title("The Annual Mean Global Surface Temperature for $e=0.2$ and $\epsilon=0$",fontsize=10)
plt.show()

# %%
# For the e03_obl0 case:

global_TS_e03_obl0=[]

for i in range(len(TS_branch_1yre03_obl0)):
    global_TS_e03_obl0.append(LatWeightAnyVar(TS_branch_1yre03_obl0[i]))
    
annual_mean_global_TS_e03_obl0=[np.mean(global_TS_e03_obl0[0:12]),
                               np.mean(global_TS_e03_obl0[12:24]),
                               np.mean(global_TS_e03_obl0[24:36]),
                               np.mean(global_TS_e03_obl0[36:48]),
                               np.mean(global_TS_e03_obl0[48:60])]


years=list(range(1,6))


diff_e03_obl0=[np.abs(i- np.mean(annual_mean_global_TS_e03_obl0)) for i in annual_mean_global_TS_e03_obl0]

fig, ax1 = plt.subplots(figsize=(8,6))
    
ax1t = ax1.twinx()

ax1.plot(years,annual_mean_global_TS_e03_obl0,'b-',label='TS')

ax1.plot((1, 5), (np.mean(annual_mean_global_TS_e03_obl0), np.mean(annual_mean_global_TS_e03_obl0)), 'k--',label='5-year average TS')

ax1t.plot(years,diff_e03_obl0,'r',label='|TS-$\overline{TS}$|')

ax1.set_xlabel('Year')
ax1.set_ylabel('Temperature in Kelvin')
ax1.legend()
ax1t.legend()

ax1t.set_ylim([0,3])
plt.title("The Annual Mean Global Surface Temperature for $e=0.3$ and $\epsilon=0$",fontsize=10)
plt.show()


print(len(global_TS_e03_obl0))

# %%
# For the branch_1yre01  case:

global_TS_branch_1yre01 =[]

for i in range(len(TS_branch_1yre01)):
    global_TS_branch_1yre01.append(LatWeightAnyVar(TS_branch_1yre01[i]))
    
annual_mean_global_TS_branch_1yre01=[np.mean(global_TS_branch_1yre01[0:12]),
                                     np.mean(global_TS_branch_1yre01[12:24]),
                                     np.mean(global_TS_branch_1yre01[24:36]),
                                     np.mean(global_TS_branch_1yre01[36:48]),
                                     np.mean(global_TS_branch_1yre01[48:60]),
                                     np.mean(global_TS_branch_1yre01[60:72]),
                                     np.mean(global_TS_branch_1yre01[72:84]),
                                     np.mean(global_TS_branch_1yre01[84:96])]

years=list(range(1,9))

diff_branch_1yre01=[np.abs(i- np.mean(annual_mean_global_TS_branch_1yre01)) for i in annual_mean_global_TS_branch_1yre01]

fig, ax1 = plt.subplots(figsize=(8,6))
    
ax1t = ax1.twinx()

ax1.plot(years,annual_mean_global_TS_branch_1yre01,'b-',label='TS')
ax1.plot((1, 8), (np.mean(annual_mean_global_TS_branch_1yre01), np.mean(annual_mean_global_TS_branch_1yre01)), 'k--',label='8-year average TS')

ax1t.plot(years,diff_branch_1yre01,'r',label='|TS-$\overline{TS}$|')

ax1.set_xlabel('Year')
ax1.set_ylabel('Temperature in Kelvin')
ax1.legend()
ax1t.legend()

ax1t.set_ylim([0,1])
plt.title("The Annual Mean Global Surface Temperature for $e=0.1$ and Default $\epsilon$",fontsize=10)
plt.show()

# %%
# For the branch_1yre01_obl0  case:

global_TS_e01_obl0 =[]

for i in range(len(TS_branch_1yre01_obl0)):
    global_TS_e01_obl0.append(LatWeightAnyVar(TS_branch_1yre01_obl0[i]))
    
annual_mean_global_TS_branch_1yre01_obl0=[np.mean(global_TS_e01_obl0[0:12]),
                                     np.mean(global_TS_e01_obl0[12:24]),
                                     np.mean(global_TS_e01_obl0[24:36]),
                                     np.mean(global_TS_e01_obl0[36:48]),
                                     np.mean(global_TS_e01_obl0[48:60]),
                                     np.mean(global_TS_e01_obl0[60:72]),
                                     np.mean(global_TS_e01_obl0[72:84]),
                                     np.mean(global_TS_e01_obl0[84:96])]

years=list(range(1,9))

diff_branch_1yre01_obl0=[np.abs(i- np.mean(annual_mean_global_TS_branch_1yre01_obl0)) for i in annual_mean_global_TS_branch_1yre01_obl0]

fig, ax1 = plt.subplots(figsize=(8,6))
    
ax1t = ax1.twinx()

ax1.plot(years,annual_mean_global_TS_branch_1yre01_obl0,'b-',label='TS')
ax1.plot((1, 8), (np.mean(annual_mean_global_TS_branch_1yre01_obl0), np.mean(annual_mean_global_TS_branch_1yre01_obl0)), 'k--',label='8-year average TS')

ax1t.plot(years,diff_branch_1yre01_obl0,'r',label='|TS-$\overline{TS}$|')

ax1.set_xlabel('Year')
ax1.set_ylabel('Temperature in Kelvin')
ax1.legend()
ax1t.legend()

ax1t.set_ylim([0,1])
plt.title("The Annual Mean Global Surface Temperature for $e=0.1$ and $\epsilon=0$",fontsize=10)
plt.show()

# %%
# For the default Earth case:

import matplotlib.patches as mpatches

global_TS_e0=[]

for i in range(len(TS_1yre0)):
    
    global_TS_e0.append(LatWeightAnyVar(TS_1yre0[i]))
    
annual_mean_global_TS_e0=[]
    
for i in range(0,8):
    
    annual_mean_global_TS_e0.append(np.mean(global_TS_e0[i*12:12*(i+1)]))
    
years=list(range(1,9))

diff_e0=[np.abs(i- np.mean(annual_mean_global_TS_e0)) for i in annual_mean_global_TS_e0]

fig, axs = plt.subplots(2, 2,sharex=True,sharey=True,figsize=(8,6))
    
ax1t = axs[0, 0].twinx()
ax2t = axs[0, 1].twinx()
ax3t = axs[1, 0].twinx()
ax4t = axs[1, 1].twinx()

l1=axs[0, 0].plot(years,annual_mean_global_TS_e0,'b-',label='TS')
l2=axs[0, 0].plot((1, 8), (np.mean(annual_mean_global_TS_e0), np.mean(annual_mean_global_TS_e0)), 'k--',
               label='8-year average TS')

axs[0, 1].plot(years,annual_mean_global_TS_e0_obl0,'b-',label='TS')
axs[0, 1].plot((1, 8), (np.mean(annual_mean_global_TS_e0_obl0), np.mean(annual_mean_global_TS_e0_obl0)), 'k--',
              label='8-year average TS')

axs[1, 0].plot(years,annual_mean_global_TS_branch_1yre01,'b-',label='TS')
axs[1, 0].plot((1, 8), (np.mean(annual_mean_global_TS_branch_1yre01), np.mean(annual_mean_global_TS_branch_1yre01)), 'k--',
              label='8-year average TS')

axs[1, 1].plot(years,annual_mean_global_TS_branch_1yre01_obl0,'b-',label='TS')
axs[1, 1].plot((1, 8), (np.mean(annual_mean_global_TS_branch_1yre01_obl0), np.mean(annual_mean_global_TS_branch_1yre01_obl0)), 'k--',
              label='8-year average TS')

ax1t.plot(years,diff_e0,'r',label='|TS-$\overline{TS}$|')
l3=ax2t.plot(years,diff_e0_obl0,'r',label='|TS-$\overline{TS}$|')
ax3t.plot(years,diff_branch_1yre01,'r',label='|TS-$\overline{TS}$|')
ax4t.plot(years,diff_branch_1yre01_obl0,'r',label='|TS-$\overline{TS}$|')

axs[0, 0].set_xticks(range(1,8))

for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Temperature in Kelvin')
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

l123 = l1+l2+l3

labs = [l.get_label() for l in l123]

fig.legend(l123, labs,bbox_to_anchor=(1, 0.6), loc='upper left')

green_patch = mpatches.Patch(color='green', label='The Default Earth')

axs[0,0].legend(handles=[green_patch])

orange_patch = mpatches.Patch(color='orange', label="Default $e$ and $\epsilon=0$")

axs[0,1].legend(handles=[orange_patch])

blue_patch = mpatches.Patch(color='blue', label="Default $e=0.1$ and default $\epsilon$")

axs[1,0].legend(handles=[blue_patch])

red_patch = mpatches.Patch(color='red', label="$e=0.1$ and $\epsilon=0$")

axs[1,1].legend(handles=[red_patch])





ax1t.set_ylim([0,1])
ax2t.set_ylim([0,1])
ax3t.set_ylim([0,1])
ax4t.set_ylim([0,1])
ax1t.set_ylabel('Temperature in Kelvin')


fig.suptitle("The Annual Mean Global Surface Temperature for Different $e$ and $\epsilon$",fontsize=12)
plt.tight_layout()
plt.show()

# %%
default_e_zero_obl= annual_mean_global_TS_e0_obl0


e01_zero_obl=annual_mean_global_TS_branch_1yre01_obl0[1:]

e02_zero_obl=annual_mean_global_TS_e02_obl0[1:]

e03_zero_obl=annual_mean_global_TS_e03_obl0[1:]


T_eq = [default_e_zero_obl, e01_zero_obl, e02_zero_obl,e03_zero_obl]

eccen=[1,2,3,4]


fig, ax1 = plt.subplots(figsize=(8,5))
    
ax1t = ax1.twinx()


for ye, xe in zip(T_eq, eccen):

    ax1.scatter([xe]*len(ye), ye, facecolors='none', edgecolors='b')

ax1.set_xticks([1,2,3,4])

ax1.set_xticklabels(['e=0.016', 'e=0.1','e=0.2','e=0.3'])

diff1=[]

for i in range(len(default_e_zero_obl)):
    
    diff1.append(default_e_zero_obl[i]-np.mean(default_e_zero_obl))
    
diff2=[]

for i in range(len(e01_zero_obl)):
    
    diff2.append(e01_zero_obl[i]-np.mean(e01_zero_obl))
    
diff3=[]

for i in range(len(e02_zero_obl)):
    
    diff3.append(e02_zero_obl[i]-np.mean(e02_zero_obl))

diff4=[]

for i in range(len(e03_zero_obl)):
    
    diff4.append(e03_zero_obl[i]-np.mean(e03_zero_obl))
    
    
yerr  = np.sum(np.abs(diff1))/len(default_e_zero_obl)

yerr2 = np.sum(np.abs(diff2))/len(e01_zero_obl)

yerr3 = np.sum(np.abs(diff3))/len(e02_zero_obl)

yerr4 = np.sum(np.abs(diff4))/len(e03_zero_obl)

print(yerr)
print(yerr2)
print(yerr3)
print(yerr4)
print(np.mean(default_e_zero_obl))
print(np.mean(e01_zero_obl))
print(np.mean(e02_zero_obl))
print(np.mean(e03_zero_obl))


ax1.errorbar(1, np.mean(default_e_zero_obl), yerr, color='red', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$287.89 +/- 0.0737$ K',alpha=0.7)
ax1.errorbar(2, np.mean(e01_zero_obl), yerr2, color='orange', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$287.88 +/- 0.0739$ K',alpha=0.7)
ax1.errorbar(3, np.mean(e02_zero_obl), yerr3, color='green', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$288.37 +/- 0.204$ K',alpha=0.7)
ax1.errorbar(4, np.mean(e03_zero_obl), yerr4, color='purple', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$290.08 +/- 0.362$ K',alpha=0.7)


flux_ratio=[1.000128, 1.00504, 1.0206, 1.0483] # flux ratio from analytic solution

ax1t.scatter([1,2,3,4],flux_ratio, marker='*',facecolors='none', edgecolors='darkgreen',label='Normalized Flux Ratio',s=60)

ax1.legend()

ax1t.legend(loc=1, bbox_to_anchor=(0.9,1))

ax1.set_xlabel('Eccentricity')
ax1.set_ylabel('$T_{eq}$ in Kelvin')
ax1t.set_ylabel('Normalized Flux')

plt.title('Equilibrium Surface Temperature vs Eccentricity')
plt.show()

# %%
default_e_zero_obl= annual_mean_global_TS_e0_obl0


e01_zero_obl=annual_mean_global_TS_branch_1yre01_obl0[1:]

e02_zero_obl=annual_mean_global_TS_e02_obl0[1:]

e03_zero_obl=annual_mean_global_TS_e03_obl0[1:]


T_eq = [default_e_zero_obl, e01_zero_obl, e02_zero_obl,e03_zero_obl]

eccen=[1,2,3,4]


fig, ax1 = plt.subplots(figsize=(8,5))
    
ax1t = ax1.twinx()


for ye, xe in zip(T_eq, eccen):

    ax1.scatter([xe]*len(ye), ye, facecolors='none', edgecolors='b')

ax1.set_xticks([1,2,3,4])

ax1.set_xticklabels(['e=0.016', 'e=0.1','e=0.2','e=0.3'])

diff1=[]

for i in range(len(default_e_zero_obl)):
    
    diff1.append(default_e_zero_obl[i]-np.mean(default_e_zero_obl))
    
diff2=[]

for i in range(len(e01_zero_obl)):
    
    diff2.append(e01_zero_obl[i]-np.mean(e01_zero_obl))
    
diff3=[]

for i in range(len(e02_zero_obl)):
    
    diff3.append(e02_zero_obl[i]-np.mean(e02_zero_obl))

diff4=[]

for i in range(len(e03_zero_obl)):
    
    diff4.append(e03_zero_obl[i]-np.mean(e03_zero_obl))
    
    
yerr  = np.sum(np.abs(diff1))/len(default_e_zero_obl)

yerr2 = np.sum(np.abs(diff2))/len(e01_zero_obl)

yerr3 = np.sum(np.abs(diff3))/len(e02_zero_obl)

yerr4 = np.sum(np.abs(diff4))/len(e03_zero_obl)


ax1.errorbar(1, np.mean(default_e_zero_obl), yerr, color='red', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$287.89 +/- 0.0737$ K',alpha=0.7)
ax1.errorbar(2, np.mean(e01_zero_obl), yerr2, color='orange', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$287.88 +/- 0.0739$ K',alpha=0.7)
ax1.errorbar(3, np.mean(e02_zero_obl), yerr3, color='green', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$288.37 +/- 0.204$ K',alpha=0.7)
ax1.errorbar(4, np.mean(e03_zero_obl), yerr4, color='purple', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$290.08 +/- 0.362$ K',alpha=0.7)


flux_ratio=[1.000128, 1.00504, 1.0206, 1.0483] # flux ratio from analytic solution

ax1t.scatter([1,2,3,4],flux_ratio, marker='*',facecolors='none', edgecolors='darkgreen',label='Normalized Flux Ratio',s=60)

ax1.legend()

ax1t.legend(loc=1, bbox_to_anchor=(0.9,1))

ax1.set_xlabel('Eccentricity')
ax1.set_ylabel('$T_{eq}$ in Kelvin')
ax1t.set_ylabel('Normalized Flux')

plt.title('Equilibrium Surface Temperature vs Eccentricity')
plt.show()

# %%
plt.figure(figsize=(10,5))

#plot the change of normalized TS vs change of normalized flux
TS=[np.mean(default_e_zero_obl), np.mean(e01_zero_obl),np.mean(e02_zero_obl),np.mean(e03_zero_obl)]

normalized_TS=[i/TS[0] for i in TS]

normalized_Delta_flux=[flux_ratio[0]-flux_ratio[0],flux_ratio[1]-flux_ratio[0],flux_ratio[2]
                       -flux_ratio[0],flux_ratio[3]-flux_ratio[0]] # change of normalized flux



normalized_Delta_TS=[normalized_TS[0]-normalized_TS[0],normalized_TS[1]-normalized_TS[0],normalized_TS[2]
                     -normalized_TS[0],normalized_TS[3]-normalized_TS[0]] # normalized change of TS


normalized_Delta_TS_error=[]


deltax_x0_squared=(yerr/TS[0])**2 # the error of normalization factor





for i in range(len([yerr2,yerr3,yerr4])):
    
    normalized_Delta_TS_error.append(((i/TS[i])**2 
                                      + deltax_x0_squared)**(1/2))  
# error propagation rule:standard deviation 

# 1st:compute the error arised from normalization of TS

# 2nd:compute the error arised from the change of TS
    
# 1st: d(x/x0)=sqrt((dx/x)^2+(dx0/x0)^2)

error_1st=[np.sqrt((yerr/TS[0])**2 +(yerr/TS[0])**2), 
           np.sqrt((yerr2/TS[1])**2+(yerr/TS[0])**2),
           np.sqrt((yerr3/TS[2])**2 + (yerr/TS[0])**2),
           np.sqrt((yerr4/TS[3])**2 + (yerr/TS[0])**2)]





fig, ax1 = plt.subplots(figsize=(8,5))
    
ax1t = ax1.twinx()

ax1t.set_yticks

ax1.errorbar(flux_ratio[0],normalized_TS[0],error_1st[0], 
             color='red', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$e=0.017$: $1 +/- 0.000362$ %',alpha=0.7)
ax1.errorbar(flux_ratio[1],normalized_TS[1],error_1st[1], 
             color='orange', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$e=0.1$:    $0.999 +/- 0.000363$ %',alpha=0.7)
ax1.errorbar(flux_ratio[2],normalized_TS[2],error_1st[2], 
             color='green', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$e=0.2$:    $1.002 +/- 0.00728$ %',alpha=0.7)
ax1.errorbar(flux_ratio[3],normalized_TS[3],error_1st[3], 
             color='purple', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$e=0.3$:    $1.009 +/- 0.00192$ %',alpha=0.7)
ax1.set_xlabel('Normalized flux',fontsize=13)
ax1.set_ylabel('Normalized TS',fontsize=13)
ax1.set_title('Normalized TS vs Normalized Flux for the Four Eccentricity Cases',fontsize=15)
ax1.legend()
plt.show()



print(normalized_TS,error_1st)

# 2nd:d(x-x0)=sqrt(dx^2+dx0^2)

error_2nd=[np.sqrt(error_1st[0]**2+error_1st[0]**2),
           np.sqrt(error_1st[1]**2+error_1st[0]**2),
           np.sqrt(error_1st[2]**2+error_1st[0]**2),
           np.sqrt(error_1st[3]**2+error_1st[0]**2)]
           
    
normalized_Delta_TS_error=[i*100 for i in normalized_Delta_TS_error]
normalized_Delta_TS=[i*100 for i in normalized_Delta_TS] 
normalized_Delta_flux=[i*100 for i in normalized_Delta_flux] 
error_2nd=[i*100 for i in error_2nd]

# multiply by 100 to get the percentage of change

plt.figure(figsize=(10,6))
plt.errorbar(normalized_Delta_flux[0],normalized_Delta_TS[0],error_2nd[0], 
             color='red', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$e=0.017$: $0 +/- 0.0512$ %',alpha=0.7)
plt.errorbar(normalized_Delta_flux[1],normalized_Delta_TS[1],error_2nd[1], 
             color='orange', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$e=0.1$:    $-0.00324 +/- 0.0513$ %',alpha=0.7)
plt.errorbar(normalized_Delta_flux[2],normalized_Delta_TS[2],error_2nd[2], 
             color='green', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$e=0.2$:    $0.205 +/- 0.0814$ %',alpha=0.7)
plt.errorbar(normalized_Delta_flux[3],normalized_Delta_TS[3],error_2nd[3], 
             color='purple', ls='none', marker='o', capsize=5, capthick=3, ecolor='black',label='$e=0.3$:    $0.921 +/- 0.195$ %',alpha=0.7)
plt.ylabel('The change of normalized TS in percentage',fontsize=13)
plt.title('$\Delta$ TS vs $\Delta$ Flux for the Four Eccentricity Cases',fontsize=15)
plt.legend()

plt.show()


print(normalized_Delta_TS)
print(error_2nd)

# %%
nmonths_e03       = list(range(1,61))

nmonths_e02       = list(range(1,67))

nmonths_e01       = list(range(1,12*8))

nmonths_e_default = list(range(1,12*8))


plt.plot(nmonths_e_default,global_TS_e0_obl0,'green')

plt.plot(nmonths_e01,global_TS_e01_obl0,'blue')

plt.plot(nmonths_e02,global_TS_e02_obl0,'orange')

plt.plot(nmonths_e03,global_TS_e03_obl0,'red')


plt.show()

# %%
#for e=0.3

Mean_yr_e0=[]
for i in range(12):
    Mean_yr_e0.append(0.2*(global_TS_e0_obl0[i]+global_TS_e0_obl0[i+12]+global_TS_e0_obl0[i+24]+global_TS_e0_obl0[i+36]+global_TS_e0_obl0[i+48]))

anomaly_e0=np.array(global_TS_e0_obl0[0:60])-np.array(Mean_yr_e0*5)

Mean_yr_e01=[]
for i in range(12):
    Mean_yr_e01.append(0.2*(global_TS_e01_obl0[i]+global_TS_e01_obl0[i+12]+global_TS_e01_obl0[i+24]+global_TS_e01_obl0[i+36]+global_TS_e0_obl0[i+48]))

anomaly_e01=np.array(global_TS_e01_obl0[0:60])-np.array(Mean_yr_e01*5)

Mean_yr_e02=[]
for i in range(12):
    Mean_yr_e02.append(0.2*(global_TS_e02_obl0[i]+global_TS_e02_obl0[i+12]+global_TS_e02_obl0[i+24]+global_TS_e02_obl0[i+36]+global_TS_e0_obl0[i+48]))

anomaly_e02=np.array(global_TS_e02_obl0[0:60])-np.array(Mean_yr_e02*5)


Mean_yr_e03=[]
for i in range(12):
    Mean_yr_e03.append(0.2*(global_TS_e03_obl0[i]+global_TS_e03_obl0[i+12]+global_TS_e03_obl0[i+24]+global_TS_e03_obl0[i+36]+global_TS_e0_obl0[i+48]))

anomaly_e03=np.array(global_TS_e03_obl0[0:60])-np.array(Mean_yr_e03*5)



yr=list(range(1,61))

plt.plot(yr,anomaly_e0,label='$e=e_{\oplus}$')
plt.plot(yr,anomaly_e01,label='$e=0.1$')
plt.plot(yr,anomaly_e02,label='$e=0.2$')
plt.plot(yr,anomaly_e03,label='$e=0.3$')


plt.title('Seasonal Anomaly of TS for 5 years')
plt.xlabel('Month')
plt.ylabel('TS in Kelvin')
plt.legend()
plt.show()

max_yr= yr[(np.asarray(anomaly_e03)).tolist().index(np.max(anomaly_e03))]

print(np.max(anomaly_e03))

print(max_yr)

# 4th max

fourth_max=np.partition(np.asarray(anomaly_e03).flatten(), -4)[-4]

print(fourth_max)

fourth_max_index=np.where(anomaly_e03 == fourth_max)

print(fourth_max_index)

print()

# %%
plt.plot(yr,np.abs(anomaly_e0),label='$e=e_{\oplus}$')
plt.plot(yr,np.abs(anomaly_e01),label='$e=0.1$')
plt.plot(yr,np.abs(anomaly_e02),label='$e=0.2$')
plt.plot(yr,np.abs(anomaly_e03),label='$e=0.3$')


plt.title('Absolute Value of Seasonal Anomaly of TS for 5 years')

plt.xticks(np.arange(0, 60, step=6))




plt.xlabel('Month')
plt.ylabel('TS in Kelvin')
plt.legend(frameon=False)
plt.show()

max_yr= yr[(np.asarray(anomaly_e03)).tolist().index(np.max(anomaly_e03))]

print(np.max(anomaly_e03))

print(max_yr)

# 4th max

fourth_max=np.partition(np.asarray(anomaly_e03).flatten(), -4)[-4]

print(fourth_max)

fourth_max_index=np.where(anomaly_e03 == fourth_max)

print(fourth_max_index)

# %%
from scipy.signal import argrelextrema



# for local maxima
print(argrelextrema(anomaly_e03, np.greater))

# for local minima
print(argrelextrema(anomaly_e03, np.less))

# %%
# The purpose of this part is to show the mean flux of the four eccentricity case: f is propto 1/r^2

days_e0,eccf_e0,true_anomaly_e0,declin_e0 = np.loadtxt('output_e_default_zero_obl.txt',unpack=True)

days_e01,eccf_e01,true_anomaly_e01,declin_e01 = np.loadtxt('output_e01_zero_obl.txt',unpack=True)

print(len(days_e01))

days_e02,eccf_e02,true_anomaly_e02,declin_e02 = np.loadtxt('output_e02_zero_obl.txt',unpack=True)

days_e03,eccf_e03,true_anomaly_e03,declin_e03 = np.loadtxt('output_e03_zero_obl.txt',unpack=True)

eccf_comb=[eccf_e0,eccf_e01,eccf_e02,eccf_e03]

dist_e0=np.sqrt(1/eccf_e0)

dist_e01=np.sqrt(1/eccf_e01)

dist_e02=np.sqrt(1/eccf_e02)

dist_e03=np.sqrt(1/eccf_e03)


flux_e0=np.mean(eccf_e0)

flux_e01=np.mean(eccf_e01)

flux_e02=np.mean(eccf_e02)

flux_e03=np.mean(eccf_e03)

flux_comb=[flux_e0,flux_e01,flux_e02,flux_e03]

print(true_anomaly_e0)


# true_anomaly_e0=(true_anomaly_e0+2*np.pi)*180/(2*np.pi)

# true_anomaly_e01=(true_anomaly_e01+2*np.pi)*180/(2*np.pi)

# true_anomaly_e02=(true_anomaly_e02+2*np.pi)*180/(2*np.pi)

# true_anomaly_e03=(true_anomaly_e03+2*np.pi)*180/(2*np.pi)

true_anomaly_comb=[true_anomaly_e0,true_anomaly_e01,true_anomaly_e02,true_anomaly_e03]

#

fig, ax1 = plt.subplots(figsize=(8,5))
    
ax1t = ax1.twinx()

ax1.plot(true_anomaly_comb[0],eccf_comb[0],label="Earth-Sun distance for default e (~ 0.016)",alpha=0.7)

ax1.plot(true_anomaly_comb[1],eccf_comb[1],label='Earth-Sun distance for e=0.1',alpha=0.7)

ax1.plot(true_anomaly_comb[2],eccf_comb[2],label='Earth-Sun distance for e=0.2',alpha=0.7)

ax1.plot(true_anomaly_comb[3],eccf_comb[3],label='Earth-Sun distance for e=0.3',alpha=0.7)

ax1.legend(loc='upper left')

plt.title('Normalized Flux vs Orbital Longitude')

ax1.set_xlabel('Orbital longitude in degrees')

ax1.set_ylabel('Normalized flux over one year')

plt.show()

#

eccen=[1,2,3,4]

plt.figure(figsize=(8,5))


plt.scatter(eccen,flux_comb,label="Annual mean flux for Earth's Eccentricity from Berger 1978")

eccen_analytic=[0.016,0.1,0.2,0.3]

flux=[]

for i in range(len(eccen_analytic)):
    
    flux.append((1-eccen_analytic[i]**2)**(-0.5))  # follow the analytic formula from paper Méndez, Abel

plt.scatter(eccen,flux,label="Temporal mean flux for Earth's Eccentricity from Mendez 2017",marker='v')


plt.xticks([1,2,3,4])

plt.axes().set_xticklabels(['e=0.016', 'e=0.1','e=0.2','e=0.3'])

plt.legend()

plt.xlabel('Eccentricity')

plt.ylabel('Normalized mean flux')

plt.title('Normalized FLux vs Eccentricity')

plt.show()

    

#
plt.figure(figsize=(8,5))

plt.plot(days_e0,true_anomaly_e0*(180/np.pi)+360,'g-',label='Earth-Sun distance for default e (~ 0.016)',alpha=0.7)

plt.plot(days_e01,true_anomaly_e01*(180/np.pi)+360,'y-',label='Earth-Sun distance for e=0.1',alpha=0.7)

plt.plot(days_e02,true_anomaly_e02*(180/np.pi)+360,'b-',label='Earth-Sun distance for e=0.2',alpha=0.7)

plt.plot(days_e03,true_anomaly_e03*(180/np.pi)+360,'r-',label='Earth-Sun distance for e=0.3',alpha=0.7)

plt.title('Location of the Earth for Each Day')

plt.xlabel('Days')

plt.ylabel('Orbital longitude of Earth in degrees')


plt.legend()

plt.show()

#




#

dist_comb=[np.mean(dist_e0),np.mean(dist_e01),np.mean(dist_e02),np.mean(dist_e03)]

eccen=[1,2,3,4]

plt.figure(figsize=(8,5))

plt.scatter(eccen,dist_comb,label="Annual mean Earth-Sun distance")

flux_comb_test=[1./(i**2) for i in dist_comb]

plt.scatter(eccen,flux_comb_test,label="Annual mean flux (geometric average)")

plt.scatter(eccen,flux_comb,label="Annual mean flux (temporal average)")

plt.xticks([1,2,3,4])

plt.axes().set_xticklabels(['e=0.016', 'e=0.1','e=0.2','e=0.3'])

plt.legend()

plt.xlabel('Eccentricity')

plt.ylabel('Orbital Distance in AU')

plt.title('Normalized Orbital Distance vs Eccentricity')
plt.show()


flux_e03_test=np.mean(1/dist_e03**2)

flux_e03_test2=1/np.mean(dist_e03)**2

flux_e03==np.mean(eccf_e03)

print(flux_e03_test)
print(flux_e03_test2)
print(np.mean(eccf_e03))

#

plt.plot(true_anomaly_e0*(180/np.pi)+360, global_TS_e0)
plt.show()

# %%
#
x_ax=np.cos(true_anomaly_e0)*dist_e0
y_ax=np.sin(true_anomaly_e0)*dist_e0

x_ax_e01=np.cos(true_anomaly_e01)*dist_e01
y_ax_e01=np.sin(true_anomaly_e01)*dist_e01

x_ax_e02=np.cos(true_anomaly_e02)*dist_e02
y_ax_e02=np.sin(true_anomaly_e02)*dist_e02

x_ax_e03=np.cos(true_anomaly_e03)*dist_e03
y_ax_e03=np.sin(true_anomaly_e03)*dist_e03

a_ax=(np.max(dist_e0)+np.min(dist_e0))/2
b_ax=a_ax*np.sqrt(1-0.01676429**2)

a_ax_e01=(np.max(dist_e01)+np.min(dist_e01))/2
b_ax_e01=a_ax_e01*np.sqrt(1-0.1**2)

a_ax_e02=(np.max(dist_e02)+np.min(dist_e02))/2
b_ax_e02=a_ax_e02*np.sqrt(1-0.2**2)

a_ax_e03=(np.max(dist_e03)+np.min(dist_e03))/2
b_ax_e03=a_ax_e03*np.sqrt(1-0.3**2)

plt.plot(x_ax,y_ax,'b',label='default e',alpha=0.6)

plt.plot(x_ax_e01,y_ax_e01,label='e=0.1',alpha=0.6)

plt.plot(x_ax_e02,y_ax_e02,label='e=0.2',alpha=0.6)



plt.plot(x_ax_e03,y_ax_e03,label='e=0.3',alpha=0.6)

plt.scatter(x_ax_e03[0],y_ax_e03[0])

plt.scatter(x_ax_e02[0],y_ax_e02[0])

plt.scatter(x_ax_e01[0],y_ax_e01[0])

plt.scatter(x_ax_e01[0],y_ax_e01[0])

plt.scatter(x_ax_e03[10],y_ax_e03[10])

plt.scatter(x_ax_e02[10],y_ax_e02[10])

plt.scatter(x_ax_e01[10],y_ax_e01[10])

plt.scatter(x_ax_e01[10],y_ax_e01[10])

plt.axis('scaled')
plt.title('Orbital Coordinate in AU')
plt.legend()
plt.show()

print(a_ax,b_ax)
print(a_ax_e01,b_ax_e01)
print(a_ax_e02,b_ax_e02)
print(a_ax_e03,b_ax_e03)

plt.plot(true_anomaly_e03,dist_e03)

plt.show()

#

eccen=[1,2,3,4]

plt.figure(figsize=(8,5))


plt.scatter(eccen,[a_ax,a_ax_e01,a_ax_e02,a_ax_e03],label="Semi-major axis for default e")

plt.scatter(eccen,[b_ax,b_ax_e01,b_ax_e02,b_ax_e03],label="Semi-minor axis for default e")

plt.xticks([1,2,3,4],['e=0.016', 'e=0.1','e=0.2','e=0.3'])


plt.legend()

plt.xlabel('Eccentricity')

plt.ylabel('Distance in AU')

plt.show()


plt.show()

# %%
plt.plot(days_e0,dist_e0)
plt.plot(days_e01,dist_e01)
plt.plot(days_e02,dist_e02)
plt.plot(days_e03,dist_e03)
plt.axvline(81,color='k')


plt.plot()

print(np.min(dist_e0))
print(np.min(dist_e01))
print(np.min(dist_e02))
print(np.min(dist_e03))

# the periastron gets closer to the Sun, when eccentricity is increased

print(days_e0[dist_e0.tolist().index(np.min(dist_e0))])

print(days_e01[dist_e01.tolist().index(np.min(dist_e01))])

print(days_e02[dist_e02.tolist().index(np.min(dist_e02))])

print(days_e03[dist_e03.tolist().index(np.min(dist_e03))])

print(type(dist_e0))

# %%
print(len(days_e01))

#days_e01,eccf_e01,true_anomaly_e01,declin_e01

# %%
y = [(1,1,2,3,9),(1,1,2,4)]
x = [1,2]

for xe, ye in zip(x, y):
    print(len(ye))
    plt.scatter([xe] * len(ye), ye)

plt.xticks([1, 2])
plt.axes().set_xticklabels(['cat1', 'cat2'])

# %%
# 0-obliquity cases

TS_e0_AVG=[]

for i in range(12):
    TS_e0_AVG.append((LatWeightAnyVar(TS_1yre0_obl0[i]) + LatWeightAnyVar(TS_1yre0_obl0[i+12]) + LatWeightAnyVar(TS_1yre0_obl0[i+24]))/3)
                

TS_e01_AVG=[]

for i in range(12):
    TS_e01_AVG.append((LatWeightAnyVar(TS_branch_1yre01_obl0[i]) + LatWeightAnyVar(TS_branch_1yre01_obl0[i+12]) + LatWeightAnyVar(TS_branch_1yre01_obl0[i+24]))/3)

yr=range(1,13)

TS_e0_AVG=[*TS_e0_AVG[-2:],*TS_e0_AVG[:10]]


TS_e01_AVG=[*TS_e01_AVG[-2:],*TS_e01_AVG[:10]]

# default obliquity cases

TS_e0_AVG_d=[]

for i in range(12):
    TS_e0_AVG_d.append((LatWeightAnyVar(TS_1yre0[i]) + LatWeightAnyVar(TS_1yre0[i+12]) + LatWeightAnyVar(TS_1yre0[i+24]))/3)
                

TS_e01_AVG_d=[]

for i in range(12):
    TS_e01_AVG_d.append((LatWeightAnyVar(TS_branch_1yre01[i]) + LatWeightAnyVar(TS_branch_1yre01[i+12]) + LatWeightAnyVar(TS_branch_1yre01[i+24]))/3)

yr=range(1,13)

TS_e0_AVG_d=[*TS_e0_AVG_d[-2:],*TS_e0_AVG_d[:10]]


TS_e01_AVG_d=[*TS_e01_AVG_d[-2:],*TS_e01_AVG_d[:10]]



#

days,eccf,declin = np.loadtxt('output_default.txt',unpack=True)


days_e01,eccf_e01,declin_e01 = np.loadtxt('output_e01.txt',unpack=True)


dist=np.sqrt(1/eccf)

dist_e01=np.sqrt(1/eccf_e01)



days_e01=np.array(days_e01)

dist_e01=np.array(dist_e01)

days=np.array(days)

dist=np.array(dist)



days=days[:12*30]/30

dist=dist[:12*30]

days_e01=days_e01[:12*30]/30

dist_e01=dist_e01[:12*30]


#start_days=[i - 12 for i in days[-60:]] # first 2 months

#days=[*start_days,*days[0:-60]] # starting from Jan



#start_days_e01=[i - 12 for i in days_e01[-60:]]

#days_e01=[*start_days_e01,*days_e01[0:-60]]


first_2=[]
later=[]
for i in days:
    if i >=13:
        first_2.append(i-12)
    if i <13:
        later.append(i)
        



first_2_e01=[]
later_e01=[]
for i in days_e01:
    if i >=13:
        first_2_e01.append(i-12)
    if i <13:
        later_e01.append(i)
        
days=[*first_2,*later]
days_e01=[*first_2_e01,*later_e01]

dist=[*dist[-60:],*dist[:300]]
dist_e01=[*dist_e01[-60:],*dist_e01[:300]]

#

fig, ax1 = plt.subplots(2, 1,figsize=(8,8))#,sharex=True,sharey=True)
    
ax1t = ax1[1].twinx()

p3,=ax1t.plot(days,dist,'g-',label='ESD for $e=e_{\oplus}$ case',alpha=0.3)

p4,=ax1t.plot(days_e01,dist_e01,'r-',label='ESD for $e=0.1$ case',alpha=0.3)


p1,=ax1[1].plot(yr,TS_e0_AVG,'g.-',label = 'TS for $e=e_{\oplus}$ and $\epsilon=0$ case',linewidth=2.2)

p2,=ax1[1].plot(yr,TS_e01_AVG,'r.-',label = 'TS for $e=0.1$ and $\epsilon=0$ case',linewidth=2.2)

ax1[1].legend(handles=[p1,p2],bbox_to_anchor=(1.13, 1), loc='upper left')

ax1t.legend(handles=[p3,p4],bbox_to_anchor=(1.13, 0.7), loc='upper left')
    
ax1t.set_ylim([0.85,1.15])

ax1t.set_ylabel('Earth-Sun Distance in AU',fontsize=13)


ax1t.set_xticks(range(1,13))


ax1[1].set_xticks(range(1,13))

#ax1.set_title('Global Surface Temperature Averaged Over Three Years',fontsize=13)
ax1[1].set_xlabel("Months",fontsize=13)
ax1[1].set_ylabel("Surface Temperature in Kelvin",fontsize=13)

#
ax1t_d = ax1[0].twinx()

p7,=ax1t_d.plot(days,dist,'g-',label='ESD for $e=e_{\oplus}$ case',alpha=0.3)

p8,=ax1t_d.plot(days_e01,dist_e01,'r-',label='ESD for $e=0.1$ case',alpha=0.3)


p5,=ax1[0].plot(yr,TS_e0_AVG_d,'g.-',label = 'TS for $e=e_{\oplus}$ and $\epsilon=\epsilon_{\oplus}$ case',linewidth=2.2)

p6,=ax1[0].plot(yr,TS_e01_AVG_d,'r.-',label = 'TS for $e=0.1$ and $\epsilon=\epsilon_{\oplus}$ case',linewidth=2.2)

ax1[0].legend(handles=[p5,p6],bbox_to_anchor=(1.13, 1), loc='upper left')

ax1t_d.legend(handles=[p7,p8],bbox_to_anchor=(1.13, 0.7), loc='upper left')
    
ax1t_d.set_ylim([0.85,1.15])

ax1t_d.set_ylabel('Earth-Sun Distance in AU',fontsize=13)


ax1t_d.set_xticks(range(1,13))


ax1[0].set_xticks(range(1,13))

#ax1.set_title('Global Surface Temperature Averaged Over Three Years',fontsize=13)
ax1[0].set_xlabel("Months",fontsize=13)
ax1[0].set_ylabel("Surface Temperature in Kelvin",fontsize=13)

# %%
days,eccf,declin = np.loadtxt('output_default.txt',unpack=True)
dist=np.sqrt(1/eccf)
plt.plot(days[365-90:365*2-90],dist[365-90:365*2-90])
plt.show()
plt.plot(days_e0,dist_e0)
plt.show()
